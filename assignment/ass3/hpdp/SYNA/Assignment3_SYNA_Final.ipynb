# %% [markdown]
# <a href="https://colab.research.google.com/github/drshahizan/Python_EDA/blob/main/assignment/ass3/hpdp/SYNA/Assignment3_SYNA_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 3 : EDA Big Data

# %% [markdown]
# ---

# %% [markdown]
# #### Group : SYNA
# #### Group Members
# #### 1. SARAH WARDINA BINTI RAFIDIN A21EC0128
# #### 2. NURUNNAJWA BINTI ZULKIFLI A21EC0121
# #### 3. ALYA DAMIA BINTI HUZAIMY A21EC0159
# #### 4. YASMEEN NATASHA BINTI HAFIZ SHAHREL A21EC0147

# %% [markdown]
# ---

# %% [markdown]
# ## 1. Dataset Selection

# %% [markdown]
# This dataset shows the life, work, and death of 1.22M people. It is a
# structured information on the life, work and death of more than 1 million people
#
# Source : https://www.kaggle.com/datasets/imoore/age-dataset/data

# %% [markdown]
# ![Screenshot (1090).png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Data Acquisition

# %% [markdown]
# The dataset is in csv format.
#
# Link : https://drive.google.com/file/d/1BeetthRHJhN7ZZk79wg2VHJra6QOCtzn/view?usp=sharing

# %% [markdown]
# ![ij.png](data:image/png;base64,...)

# %% [markdown]
# ---

# %% [markdown]
# ## 3. Setting Up the Environment

# %% [markdown]
# 1. First, we mounted the G Drive to import the dataset
# - This step is specific to Google Colab and helps you mount your Google Drive to access files.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# 2. Import necessary libraries
#
# - This code imports the necessary libraries for data manipulation and analysis.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# - *pandas* is a powerful library for data manipulation and analysis. It provides data structures like DataFrame for working with structured data, and it includes a variety of functions for cleaning, transforming, and analyzing data.
#
# - *numpy* is a library for numerical operations in Python. It provides support for large, multi-dimensional arrays and matrices, along with mathematical functions to operate on these arrays.

# %% [markdown]
# 3. We need to load the dataset
# - Load your dataset using Pandas. df is a common convention for a DataFrame, which is a tabular data structure in Pandas.

# %%
df = pd.read_csv("drive/MyDrive/AgeDataset-V1.csv")
df
# Out:
#                 Id                     Name  \
# 0              Q23        George Washington
# 1              Q42            Douglas Adams
# 2              Q91          Abraham Lincoln
# 3             Q254  Wolfgang Amadeus Mozart
# 4             Q255     Ludwig van Beethoven
# ...            ...                      ...
# 1223004  Q77247326    Marie-Fortunée Besson
# 1223005  Q77249504              Ron Thorsen
# 1223006  Q77249818       Diether Todenhagen
# 1223007  Q77253909  Reginald Oswald Pearson
# 1223008  Q77254864             Horst Lerche
#
#                                          Short description Gender  \
# 0           1st president of the United States (1732–1799)   Male
# 1                              English writer and humorist   Male
# 2          16th president of the United States (1809-1865)   Male
# 3                Austrian composer of the Classical period   Male
# 4                   German classical and romantic composer   Male
# ...                                                    ...    ...
# 1223004                            Frans model (1907-1996)    NaN
# 1223005        xugador de baloncestu canadianu (1948–2004)    NaN
# 1223006  German navy officer and world war II U-boat co...    NaN
# 1223007  English artist, working in stained glass, prin...   Male
# 1223008                                     German painter   Male
#
#                                                    Country  \
# 0        United States of America; Kingdom of Great Bri...
# 1                                           United Kingdom
# 2                                 United States of America
# 3          Archduchy of Austria; Archbishopric of Salzburg
# 4                       Holy Roman Empire; Austrian Empire
# ...                                                    ...
# 1223004                                             France
# 1223005                   Canada; United States of America
# 1223006                                            Germany
# 1223007                                     United Kingdom
# 1223008                                            Germany
#
#                  Occupation  Birth year  Death year Manner of death  \
# 0                Politician        1732      1799.0  natural causes
# 1                    Artist        1952      2001.0  natural causes
# 2                Politician        1809      1865.0        homicide
# 3                    Artist        1756      1791.0             NaN
# 4                    Artist        1770      1827.0             NaN
# ...                     ...         ...         ...             ...
# 1223004       Tailor; model        1907      1996.0             NaN
# 1223005             Athlete        1948      2004.0             NaN
# 1223006  Military personnel        1920      1944.0             NaN
# 1223007              Artist        1887      1915.0             NaN
# 1223008              Artist        1938      2017.0             NaN
#
#          Age of death
# 0                67.0
# 1                49.0
# 2                56.0
# 3                35.0
# 4                57.0
# ...               ...
# 1223004          89.0
# 1223005          56.0
# 1223006          24.0
# 1223007          28.0
# 1223008          79.0
#
# [1223009 rows x 10 columns]

# %% [markdown]
# - The table above show 1 to 25 entries of dataset

# %% [markdown]
# 4. Display the few first line of dataset

# %%
df.head()
# Out:
#      Id                     Name  \
# 0   Q23        George Washington
# 1   Q42            Douglas Adams
# 2   Q91          Abraham Lincoln
# 3  Q254  Wolfgang Amadeus Mozart
# 4  Q255     Ludwig van Beethoven
#
#                                  Short description Gender  \
# 0   1st president of the United States (1732–1799)   Male
# 1                      English writer and humorist   Male
# 2  16th president of the United States (1809-1865)   Male
# 3        Austrian composer of the Classical period   Male
# 4           German classical and romantic composer   Male
#
#                                              Country  Occupation  Birth year  \
# 0  United States of America; Kingdom of Great Bri...  Politician        1732
# 1                                     United Kingdom      Artist        1952
# 2                           United States of America  Politician        1809
# 3    Archduchy of Austria; Archbishopric of Salzburg      Artist        1756
# 4                 Holy Roman Empire; Austrian Empire      Artist        1770
#
#    Death year Manner of death  Age of death
# 0      1799.0  natural causes          67.0
# 1      2001.0  natural causes          49.0
# 2      1865.0        homicide          56.0
# 3      1791.0             NaN          35.0
# 4      1827.0             NaN          57.0

# %% [markdown]
# - This shows you the first few rows of your dataset to get an overview of the data.

# %% [markdown]
# 5. We need to explore the dataset to know more depth about the dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1223009 entries, 0 to 1223008
# Data columns (total 10 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   Id                 1223009 non-null  object
#  1   Name               1223009 non-null  object
#  2   Short description  1155109 non-null  object
#  3   Gender             1089363 non-null  object
#  4   Country            887500 non-null   object
#  5   Occupation         1016095 non-null  object
#  6   Birth year         1223009 non-null  int64
#  7   Death year         1223008 non-null  float64
#  8   Manner of death    53603 non-null    object
#  9   Age of death       1223008 non-null  float64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 93.3+ MB

# %% [markdown]
# - These commands provide information about the dataset, such as data types, missing values, and statistics.

# %% [markdown]
# **DataFrame Information** :
#
# - <class 'pandas.core.frame.DataFrame'>: This line indicates that the variable is a Pandas DataFrame.
# Index Information:
#
# - RangeIndex: 1223009 entries, 0 to 1223008: The index information shows that the DataFrame has a RangeIndex (similar to Python's built-in range) with 1223009 entries, ranging from 0 to 1223008.
# Column Information:
#
# - Data columns (total 10 columns): There are a total of 10 columns in the DataFrame.
#
# **Column Details**:
#
# - Each column is listed with its name, the number of non-null (non-missing) values, and the data type.
# - Non-Null Count: Indicates how many non-null values are present in each column.
# - Dtype: Specifies the data type of each column.
#
# **Memory Usage Information**:
#
# - memory usage: 93.3+ MB: Shows the memory usage of the DataFrame. The + indicates that this is an estimate, and the actual memory usage might be higher.

# %% [markdown]
# ---

# %% [markdown]
# ## 4. Data Preprocessing

# %% [markdown]
# 6. Now, we need to handle missing values

# %%
df.fillna(df.mode().iloc[0], inplace=True)

# %% [markdown]
# - In simple terms, df.fillna(df.mode().iloc[0], inplace=True) fills in missing values in the DataFrame with the most frequent value (mode) of each column. It's a common strategy for handling missing values in categorical or discrete data where using the mode makes sense.
#
# - For example, if you have a column representing death cause and some entries are missing, this line of code would fill those missing values with the most common death cause in the dataset.

# %%
df.drop(df[df['Age of death'] == 0].index, inplace=True)

# %% [markdown]
# 7. We handle the duplicates value invour dataset

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# - The entire line of code is dropping (removing) the rows from the DataFrame where the 'Age of death' column has a value of 0. The changes are applied directly to the original DataFrame. After running this line, the DataFrame will no longer contain rows where 'Age of death' is equal to 0.

# %% [markdown]
# - Here, we remove duplicate rows from dataset.

# %%
df.head()
# Out:
#      Id                     Name  \
# 0   Q23        George Washington
# 1   Q42            Douglas Adams
# 2   Q91          Abraham Lincoln
# 3  Q254  Wolfgang Amadeus Mozart
# 4  Q255     Ludwig van Beethoven
#
#                                  Short description Gender  \
# 0   1st president of the United States (1732–1799)   Male
# 1                      English writer and humorist   Male
# 2  16th president of the United States (1809-1865)   Male
# 3        Austrian composer of the Classical period   Male
# 4           German classical and romantic composer   Male
#
#                                              Country  Occupation  Birth year  \
# 0  United States of America; Kingdom of Great Bri...  Politician        1732
# 1                                     United Kingdom      Artist        1952
# 2                           United States of America  Politician        1809
# 3    Archduchy of Austria; Archbishopric of Salzburg      Artist        1756
# 4                 Holy Roman Empire; Austrian Empire      Artist        1770
#
#    Death year Manner of death  Age of death
# 0      1799.0  natural causes          67.0
# 1      2001.0  natural causes          49.0
# 2      1865.0        homicide          56.0
# 3      1791.0  natural causes          35.0
# 4      1827.0  natural causes          57.0

# %%
df.tail()
# Out:
#                 Id                     Name  \
# 1223004  Q77247326    Marie-Fortunée Besson
# 1223005  Q77249504              Ron Thorsen
# 1223006  Q77249818       Diether Todenhagen
# 1223007  Q77253909  Reginald Oswald Pearson
# 1223008  Q77254864             Horst Lerche
#
#                                          Short description Gender  \
# 1223004                            Frans model (1907-1996)   Male
# 1223005        xugador de baloncestu canadianu (1948–2004)   Male
# 1223006  German navy officer and world war II U-boat co...   Male
# 1223007  English artist, working in stained glass, prin...   Male
# 1223008                                     German painter   Male
#
#                                   Country          Occupation  Birth year  \
# 1223004                            France       Tailor; model        1907
# 1223005  Canada; United States of America             Athlete        1948
# 1223006                           Germany  Military personnel        1920
# 1223007                    United Kingdom              Artist        1887
# 1223008                           Germany              Artist        1938
#
#          Death year Manner of death  Age of death
# 1223004      1996.0  natural causes          89.0
# 1223005      2004.0  natural causes          56.0
# 1223006      1944.0  natural causes          24.0
# 1223007      1915.0  natural causes          28.0
# 1223008      2017.0  natural causes          79.0

# %% [markdown]
# - The df.head() and df.tail() functions are used in Pandas to display the first few and last few rows of a DataFrame, respectively. They are helpful for quickly inspecting the structure and contents of the DataFrame.

# %% [markdown]
# - This is useful for getting a quick glimpse of the dataset, understanding the column names, and checking the initial values.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1222769 entries, 0 to 1223008
# Data columns (total 10 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   Id                 1222769 non-null  object
#  1   Name               1222769 non-null  object
#  2   Short description  1222769 non-null  object
#  3   Gender             1222769 non-null  object
#  4   Country            1222769 non-null  object
#  5   Occupation         1222769 non-null  object
#  6   Birth year         1222769 non-null  int64
#  7   Death year         1222769 non-null  float64
#  8   Manner of death    1222769 non-null  object
#  9   Age of death       1222769 non-null  float64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 102.6+ MB

# %% [markdown]
# - In this dataset, it seems that there are no missing values in any of the columns, as the "Non-Null Count" for each column is equal to the total number of entries (1223007).

# %%
for column in  df.columns:
  if df[column].dtype == 'float64':
    df[column]=df[column].astype('float16')
  if df[column].dtype == 'int64' :
    df [column]= df[column].astype('int16')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1222769 entries, 0 to 1223008
# Data columns (total 10 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   Id                 1222769 non-null  object
#  1   Name               1222769 non-null  object
#  2   Short description  1222769 non-null  object
#  3   Gender             1222769 non-null  object
#  4   Country            1222769 non-null  object
#  5   Occupation         1222769 non-null  object
#  6   Birth year         1222769 non-null  int16
#  7   Death year         1222769 non-null  float16
#  8   Manner of death    1222769 non-null  object
#  9   Age of death       1222769 non-null  float16
# dtypes: float16(2), int16(1), object(7)
# memory usage: 81.6+ MB

# %% [markdown]
# 8. After cleaning, we can save our dataset as *Cleaned_AgeDataset_SYN.csv*

# %%
cleaned_file_path = "/content/drive/MyDrive/Cleaned_AgeDataset_SYN.csv"
df.to_csv(cleaned_file_path, index=False)

# %% [markdown]
# 9. Now, we can confirm the changes.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1222769 entries, 0 to 1223008
# Data columns (total 10 columns):
#  #   Column             Non-Null Count    Dtype
# ---  ------             --------------    -----
#  0   Id                 1222769 non-null  object
#  1   Name               1222769 non-null  object
#  2   Short description  1222769 non-null  object
#  3   Gender             1222769 non-null  object
#  4   Country            1222769 non-null  object
#  5   Occupation         1222769 non-null  object
#  6   Birth year         1222769 non-null  int16
#  7   Death year         1222769 non-null  float16
#  8   Manner of death    1222769 non-null  object
#  9   Age of death       1222769 non-null  float16
# dtypes: float16(2), int16(1), object(7)
# memory usage: 81.6+ MB

# %%
df.head()
# Out:
#      Id                     Name  \
# 0   Q23        George Washington
# 1   Q42            Douglas Adams
# 2   Q91          Abraham Lincoln
# 3  Q254  Wolfgang Amadeus Mozart
# 4  Q255     Ludwig van Beethoven
#
#                                  Short description Gender  \
# 0   1st president of the United States (1732–1799)   Male
# 1                      English writer and humorist   Male
# 2  16th president of the United States (1809-1865)   Male
# 3        Austrian composer of the Classical period   Male
# 4           German classical and romantic composer   Male
#
#                                              Country  Occupation  Birth year  \
# 0  United States of America; Kingdom of Great Bri...  Politician        1732
# 1                                     United Kingdom      Artist        1952
# 2                           United States of America  Politician        1809
# 3    Archduchy of Austria; Archbishopric of Salzburg      Artist        1756
# 4                 Holy Roman Empire; Austrian Empire      Artist        1770
#
#    Death year Manner of death  Age of death
# 0      1799.0  natural causes          67.0
# 1      2001.0  natural causes          49.0
# 2      1865.0        homicide          56.0
# 3      1791.0  natural causes          35.0
# 4      1827.0  natural causes          57.0

# %% [markdown]
# 10. Now, we have finished the data prepping and cleaning.

# %% [markdown]
# ### Importing the Libraries

# %%
import pandas as pd
import gc
import glob
import os

# %% [markdown]
# #### Chunking

# %%
import pandas as pd

cleaned_file_path = "/content/drive/MyDrive/Cleaned_AgeDataset_SYN.csv"

# Chunk size
chunk_size = 100000 # Adjust this value based on your preferences

# Read the CSV file in chunks
for i, chunk in enumerate(pd.read_csv(cleaned_file_path, chunksize=chunk_size)):
    # Process each chunk as needed
    # For example, you can print the shape of each chunk
    print(f"Chunk {i+1} Shape: {chunk.shape}")

    # Perform additional processing on each chunk if necessary

    # Save the chunk to a separate CSV file
    chunk.to_csv(f"{cleaned_file_path}_chunk_{i+1}.csv", index=False)
# Out:
# Chunk 1 Shape: (100000, 10)
# Chunk 2 Shape: (100000, 10)
# Chunk 3 Shape: (100000, 10)
# Chunk 4 Shape: (100000, 10)
# Chunk 5 Shape: (100000, 10)
# Chunk 6 Shape: (100000, 10)
# Chunk 7 Shape: (100000, 10)
# Chunk 8 Shape: (100000, 10)
# Chunk 9 Shape: (100000, 10)
# Chunk 10 Shape: (100000, 10)
# Chunk 11 Shape: (100000, 10)
# Chunk 12 Shape: (100000, 10)
# Chunk 13 Shape: (22769, 10)

# %%
# Information about the chunk
chunk_info = f"Chunk {i+1} Info:\n{chunk.info()}\n"

# Print or log the chunk information
print(chunk_info)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22769 entries, 1200000 to 1222768
# Data columns (total 10 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Id                 22769 non-null  object
#  1   Name               22769 non-null  object
#  2   Short description  22769 non-null  object
#  3   Gender             22769 non-null  object
#  4   Country            22769 non-null  object
#  5   Occupation         22769 non-null  object
#  6   Birth year         22769 non-null  int64
#  7   Death year         22769 non-null  float64
#  8   Manner of death    22769 non-null  object
#  9   Age of death       22769 non-null  float64
# dtypes: float64(2), int64(1), object(7)
# memory usage: 1.7+ MB
# Chunk 13 Info:
# None

# %%
# Read the CSV file in chunks
for i, chunk in enumerate(pd.read_csv(cleaned_file_path, chunksize=chunk_size)):

    print(f"Exploratory Data Analysis for Chunk {i+1}:")

    # Display basic statistics for numerical columns
    print(chunk.describe())

    # Display the first few rows of the chunk
    print(chunk.head())

    # Display the data types of columns
    print(chunk.dtypes)
# Out:
# Exploratory Data Analysis for Chunk 1:
#           Birth year     Death year   Age of death
# count  100000.000000  100000.000000  100000.000000
# mean     1790.762830    1858.963600      68.201340
# std       266.548417     271.272039      17.133007
# min     -2284.000000   -2200.000000       1.000000
# 25%      1796.000000    1861.000000      58.000000
# 50%      1880.000000    1945.000000      71.000000
# 75%      1914.000000    1991.000000      81.000000
# max      2002.000000    2021.000000     122.000000
#      Id                     Name  \
# 0   Q23        George Washington
# 1   Q42            Douglas Adams
# 2   Q91          Abraham Lincoln
# 3  Q254  Wolfgang Amadeus Mozart
# 4  Q255     Ludwig van Beethoven
#
#                                  Short description Gender  \
# 0   1st president of the United States (1732–1799)   Male
# 1                      English writer and humorist   Male
# 2  16th president of the United States (1809-1865)   Male
# 3        Austrian composer of the Classical period   Male
# 4           German classical and romantic composer   Male
#
#                                              Country  Occupation  Birth year  \
# 0  United States of America; Kingdom of Great Bri...  Politician        1732
# 1                                     United Kingdom      Artist        1952
# 2                           United States of America  Politician        1809
# 3    Archduchy of Austria; Archbishopric of Salzburg      Artist        1756
# 4                 Holy Roman Empire; Austrian Empire      Artist        1770
#
#    Death year Manner of death  Age of death
# 0      1799.0  natural causes          67.0
# 1      2001.0  natural causes          49.0
# 2      1865.0        homicide          56.0
# 3      1791.0  natural causes          35.0
# 4      1827.0  natural causes          57.0
# Id                    object
# Name                  object
# Short description     object
# Gender                object
# Country               object
# Occupation            object
# Birth year             int64
# Death year           float64
# Manner of death       object
# Age of death         float64
# dtype: object
# Exploratory Data Analysis for Chunk 2:
#           Birth year     Death year   Age of death
# count  100000.000000  100000.000000  100000.000000
# mean     1831.668800    1901.383910      69.715120
# std       190.917446     194.997813      15.899792
# min     -2700.000000   -2660.000000       2.000000
# 25%      1823.000000    1891.000000      61.000000
# 50%      1887.000000    1957.000000      72.000000
# 75%      1919.000000    1995.000000      81.000000
# max      2000.000000    2021.000000     130.000000
#              Id                   Name  \
# 100000  Q729712       Nikolay Baransky
# 100001  Q729722      Robert Le Lorrain
# 100002  Q729734        Kees Pellenaars
# 100003  Q729743      Georges d'Amboise
# 100004  Q729751  Scaramuccia Trivulzio
#
#                                  Short description Gender  \
# 100000                          Russian geographer   Male
# 100001                             French sculptor   Male
# 100002                               Dutch cyclist   Male
# 100003  Cardinal and minister of state (1460-1510)   Male
# 100004                           Catholic cardinal   Male
#
#                                                   Country        Occupation  \
# 100000  Soviet Union; Russian Empire; Russian Republic...        Geographer
# 100001                                             France            Artist
# 100002                         Kingdom of the Netherlands           Athlete
# 100003                                             France        Politician
# 100004                                             France  Religious figure
#
#         Birth year  Death year Manner of death  Age of death
# 100000        1881      1963.0  natural causes          82.0
# 100001        1666      1743.0  natural causes          77.0
# 100002        1913      1988.0  natural causes          75.0
# 100003        1460      1510.0  natural causes          50.0
# 100004        1465      1527.0  natural causes          62.0
# Id                    object
# Name                  object
# Short description     object
# Gender                object
# Country               object
# Occupation            object
# Birth year             int64
# Death year           float64
# Manner of death       object
# Age of death         float64
# dtype: object
# Exploratory Data Analysis for Chunk 3:
#           Birth year     Death year  Age of death
# count  100000.000000  100000.000000  100000.00000
# mean     1834.049470    1903.461470      69.41200
# std       158.902647     163.091683      16.26924
# min      -750.000000    -730.000000       1.00000
# 25%      1816.000000    1884.000000      60.00000
# 50%      1886.000000    1954.000000      72.00000
# 75%      1918.000000    1995.000000      81.00000
# max      2000.000000    2021.000000     119.00000
#               Id               Name  \
# 200000  Q1683584    Jaromír Kopecký
# 200001  Q1683605     Jaroslav Beneš
# 200002  Q1683607    Jaroslav Bouček
# 200003  Q1683609  Jaroslav Chundela
# 200004  Q1683610    Jaroslav Fikejz
#
#                                         Short description Gender  \
# 200000                                         embassador   Male
# 200001  Czech philosopher, professor, theologist, univ...   Male
# 200002                       Czech footballer (1912-1987)   Male
# 200003                                        Czech actor   Male
# 200004          Czech sports official and sport publicist   Male
#
#                                Country  Occupation  Birth year  Death year  \
# 200000        United States of America  Politician        1899      1977.0
# 200001                  Czech Republic      Artist        1892      1963.0
# 200002  Czech Republic; Czechoslovakia     Athlete        1912      1987.0
# 200003                  Czech Republic      Artist        1936      1995.0
# 200004  Czech Republic; Czechoslovakia     Athlete        1927      2008.0
#
#        Manner of death  Age of death
# 200000  natural causes          78.0
# 200001  natural causes          71.0
# 200002  natural causes          75.0
# 200003  natural causes          59.0
# 200004  natural causes          81.0
# Id                    object
# Name                  object
# Short description     object
# Gender                object
# Country               object
# Occupation            object
# Birth year             int64
# Death year           float64
# Manner of death       object
# Age of death         float64
# dtype: object
# Exploratory Data Analysis for Chunk 4:
#           Birth year     Death year   Age of death
# count  100000.000000  100000.000000  100000.000000
# mean     1847.916560    1916.542340      68.625780
# std       143.588319     146.786539      17.052267
# min      -790.000000    -750.000000       1.000000
# 25%      1830.000000    1897.000000      59.000000
# 50%      1894.000000    1961.000000      72.000000
# 75%      1921.000000    1997.000000      81.000000
# max      2007.000000    2021.000000     128.000000
#               Id                 Name                Short description Gender  \
# 300000  Q3123759      Gérard Bessette                  Canadian writer   Male
# 300001  Q3123760  Gérard Bialestowski             French author & poet   Male
# 300002  Q3123767     Gérard Blanchard  French engraver and typographer   Male
# 300003  Q3123771     Gérard Bobillier                 French publisher   Male
# 300004  Q3123772         Gérard Boche                French politician   Male
#
#        Country  Occupation  Birth year  Death year Manner of death  \
# 300000  Canada      Artist        1920      2005.0  natural causes
# 300001  France      Artist        1946      2007.0  natural causes
# 300002  France      Artist        1927      1998.0  natural causes
# 300003  France   Publisher        1945      2009.0  natural causes
# 300004  France  Politician        1930      1999.0  natural causes
#
#         Age of death
# 300000          85.0
# 300001          61.0
# 300002          71.0
# 300003          64.0
# 300004          69.0
# Id                    object
# Name                  object
# Short description     object
# Gender                object
# Country               object
# Occupation            object
# Birth year             int64
# Death year           float64
# Manner of death       object
# Age of death         float64
# dtype: object
# Exploratory Data Analysis for Chunk 5:
#           Birth year     Death year   Age of death
# count  100000.000000  100000.000000  100000.000000
# mean     1866.339400    1936.741410      70.402010
# std       105.127298     108.452541      16.387584
# min      -800.000000    -728.000000       1.000000
# 25%      1851.000000    1918.000000      61.000000
# 50%      1892.000000    1964.000000      73.000000
# 75%      1919.000000    1997.000000      82.000000
# max      2003.000000    2021.000000     169.000000
#               Id            Name                       Short description  \
# 400000  Q4706658     Alan Furlan               Italian actor (1920-1997)
# 400001  Q4706662  Alan G. Merten         American academic administrator
# 400002  Q4706663      Alan Scott  Australian rules footballer, born 1900
# 400003  Q4706665  Alan G. Thomas                          British writer
# 400004  Q4706666       Alan Gale             Australian rules footballer
#
#        Gender                   Country Occupation  Birth year  Death year  \
# 400000   Male  United States of America     Artist        1920      1997.0
# 400001   Male  United States of America     Artist        1941      2020.0
# 400002   Male  United States of America    Athlete        1900      1982.0
# 400003   Male  United States of America     Artist        1911      1992.0
# 400004   Male  United States of America    Athlete        1930      1987.0
#
#        Manner of death  Age of death
# 400000  natural causes          77.0
# 400001  natural causes          79.0
# 400002  natural causes          82.0
# 400003  natural causes          81.0
# 400004  natural causes          57.0
# Id                    object
# Name                  object
# Short description     object
# Gender                object
# Country               object
# Occupation            object
# Birth year             int64
# Death year           float64
# Manner of death       object
# Age of death         float64
# dtype: object
# Exploratory Data Analysis for Chunk 6:
#           Birth year     Death year   Age of death
# count  100000.000000  100000.000000  100000.000000
# mean     1860.934740    1930.896580      69.961840
# std       117.225043     120.635179      16.391021
# min      -532.000000    -483.000000       1.000000
# 25%      1842.000000    1909.000000      61.000000
# 50%      1894.000000    1965.000000      73.000000
# 75%      1922.000000    2000.000000      82.000000
# max      2003.000000    2021.000000     132.000000
#               Id                  Name  \
# 500000  Q5729156    Henry Thomas Riley
# 500001  Q5729159       Carl von Fersen
# 500002  Q5729161    Henry Thomas Ryall
# 500003  Q5729164  Henry Thomas Windsor
# 500004  Q5729167   Henry Thorne Morton
#
#                                         Short description Gender  \
# 500000  British translator, lexicographer and antiquar...   Male
# 500001                      funcionariu suecu (1716–1786)   Male
# 500002                                             artist   Male
# 500003                            American postal pioneer   Male
# 500004                             New Zealand politician   Male
#
#                                             Country  Occupation  Birth year  \
# 500000                     United States of America  Translator        1816
# 500001                                       Sweden      Artist        1716
# 500002  United Kingdom of Great Britain and Ireland      Artist        1811
# 500003                     United States of America      Artist        1796
# 500004                                  New Zealand  Politician        1888
#
#         Death year Manner of death  Age of death
# 500000      1878.0  natural causes          62.0
# 500001      1786.0  natural causes          70.0
# 500002      1867.0  natural causes          56.0
# 500003      1848.0  natural causes          52.0
# 500004      1966.0  natural causes          78.0
# Id                    object
# Name                  object
# Short description     object
# Gender                object
# Country               object
# Occupation            object
# Birth year             int64
# Death year           float64
# Manner of death       object
# Age of death         float64
# dtype: object
# Exploratory Data Analysis for Chunk 7:
#           Birth year     Death year   Age of death
# count  100000.000000  100000.000000  100000.000000
# mean     1846.021460    1914.701330      68.679870
# std       166.643438     170.626457      17.525582
# min      -720.000000    -621.000000       1.000000
# 25%      1837.000000    1903.000000      59.000000
# 50%      1895.000000    1965.000000      72.000000
# 75%      1922.000000    2000.000000      82.000000
# max      2005.000000    2021.000000     119.000000
#               Id           Name  \
# 600000  Q7307798       Reg Hope
# 600001  Q7307799      Reg Horne
# 600002  Q7307800  Reg Humphries
# 600003  Q7307802    Reg Isidore
# 600004  Q7307804    Reg Johnson
#
#                                         Short description Gender  \
# 600000        Member of the Tasmanian Legislative Council   Male
# 600001                                professional golfer   Male
# 600002                              Australian footballer   Male
# 600003                                   British musician   Male
# 600004  Australian cartographer, ornithologist and env...   Male
#
#                          Country  \
# 600000                 Australia
# 600001  United States of America
# 600002  United States of America
# 600003                     Aruba
# 600004                 Australia
#
#                                            Occupation  Birth year  Death year  \
# 600000                                     Politician        1927      2010.0
# 600001                                        Athlete        1908      1984.0
# 600002                                        Athlete        1911      1986.0
# 600003                                         Artist        1949      2009.0
# 600004  Ornithologist; cartographer; environmentalist        1921      2011.0
#
#        Manner of death  Age of death
# 600000  natural causes          83.0
# 600001  natural causes          76.0
# 600002  natural causes          75.0
# 600003  natural causes          60.0
# 600004  natural causes          90.0
# Id                    object
# Name                  object
# Short description     object
# Gender                object
# Country               object
# Occupation            object
# Birth year             int64
# Death year           float64
# Manner of death       object
# Age of death         float64
# dtype: object
# Exploratory Data Analysis for Chunk 8:
#           Birth year     Death year   Age of death
# count  100000.000000  100000.000000  100000.000000
# mean     1868.195860    1937.868270      69.672410
# std       102.549132     105.514658      16.344389
# min      -500.000000    -465.000000       1.000000
# 25%      1856.000000    1922.000000      61.000000
# 50%      1895.000000    1965.000000      72.000000
# 75%      1919.000000    1995.000000      82.000000
# max      2004.000000    2021.000000     128.000000
#                Id                    Name       Short description Gender  \
# 700000  Q11717445  Jean-Philippe Marchand  French Catholic priest   Male
# 700001  Q11717448            Jan Filipiak     American politician   Male
# 700002  Q11717451          Jan Filipowicz         biskup kijowski   Male
# 700003  Q11717457          Jan Flasieński               schrijver   Male
# 700004  Q11717458                Jan Flis          polski geograf   Male
#
#                          Country        Occupation  Birth year  Death year  \
# 700000  United States of America  Religious figure        1764      1792.0
# 700001                    Poland            Artist        1881      1946.0
# 700002  United States of America            Artist        1480      1537.0
# 700003  United States of America            Artist        1789      1852.0
# 700004                    Poland            Artist        1912      1993.0
#
#        Manner of death  Age of death
# 700000  natural causes          28.0
# 700001  natural causes          65.0
# 700002  natural causes          57.0
# 700003  natural causes          63.0
# 700004  natural causes          81.0
# Id                    object
# Name                  object
# Short description     object
# Gender                object
# Country               object
# Occupation            object
# Birth year             int64
# Death year           float64
# Manner of death       object
# Age of death         float64
# dtype: object
# Exploratory Data Analysis for Chunk 9:
#           Birth year     Death year   Age of death
# count  100000.000000  100000.000000  100000.000000
# mean     1848.744090    1917.907960      69.163870
# std       118.153844     121.918605      16.623606
# min      -350.000000    -284.000000       1.000000
# 25%      1823.000000    1891.000000      60.000000
# 50%      1883.000000    1948.000000      72.000000
# 75%      1918.000000    1995.000000      81.000000
# max      2010.000000    2021.000000     119.000000
#                Id              Name                       Short description  \
# 800000  Q16014993  Charles Spearman                 American football coach
# 800001  Q16014994      Bob Stainton           English cricketer (1910-2000)
# 800002  Q16014995   Irving I. Stone  Founder-chairman of American Greetings
# 800003  Q16014996      George Story                     American journalist
# 800004  Q16014997      Ray Sturgess             cinematographer (1910-2000)
#
#        Gender                                            Country  \
# 800000   Male                           United States of America
# 800001   Male  United Kingdom; United Kingdom of Great Britai...
# 800002   Male                           United States of America
# 800003   Male                           United States of America
# 800004   Male  United Kingdom; United Kingdom of Great Britai...
#
#              Occupation  Birth year  Death year Manner of death  Age of death
# 800000          Athlete        1913      2000.0  natural causes          87.0
# 800001          Athlete        1910      2000.0  natural causes          90.0
# 800002           Artist        1909      2000.0  natural causes          91.0
# 800003       Journalist        1936      2000.0  natural causes          64.0
# 800004  Cinematographer        1910      2000.0  natural causes          90.0
# Id                    object
# Name                  object
# Short description     object
# Gender                object
# Country               object
# Occupation            object
# Birth year             int64
# Death year           float64
# Manner of death       object
# Age of death         float64
# dtype: object
# Exploratory Data Analysis for Chunk 10:
#           Birth year     Death year   Age of death
# count  100000.000000  100000.000000  100000.000000
# mean     1856.767080    1927.014450      70.247370
# std        94.879937      98.556575      16.023234
# min      -200.000000    -106.000000       1.000000
# 25%      1833.000000    1900.000000      61.000000
# 50%      1882.000000    1951.000000      73.000000
# 75%      1913.000000    1989.000000      82.000000
# max      2012.000000    2021.000000     119.000000
#                Id                          Name  \
# 900000  Q18945469  Girolamo Francesco Cristiani
# 900001  Q18945471             Girolamo Manfredi
# 900002  Q18945472    Girolamo Pietro Cortinovis
# 900003  Q18945482           Giuseppe Calligaris
# 900004  Q18945484             Giuseppe Mascardi
#
#                                         Short description Gender  \
# 900000                                          1731-1811   Male
# 900001  1430-1493 Italian philosopher, physician and a...   Male
# 900002               Italian mathematician (18th century)   Male
# 900003                                          1865-1912   Male
# 900004                              lawyer (18th century)   Male
#
#                          Country      Occupation  Birth year  Death year  \
# 900000  United States of America  Businessperson        1731      1811.0
# 900001       Lordship of Bologna       Physician        1430      1493.0
# 900002  United States of America      Researcher        1701      1800.0
# 900003  United States of America      Researcher        1865      1912.0
# 900004  United States of America          Lawyer        1701      1800.0
#
#        Manner of death  Age of death
# 900000  natural causes          80.0
# 900001  natural causes          63.0
# 900002  natural causes          99.0
# 900003  natural causes          47.0
# 900004  natural causes          99.0
# Id                    object
# Name                  object
# Short description     object
# Gender                object
# Country               object
# Occupation            object
# Birth year             int64
# Death year           float64
# Manner of death       object
# Age of death         float64
# dtype: object
# Exploratory Data Analysis for Chunk 11:
#           Birth year     Death year   Age of death
# count  100000.000000  100000.000000  100000.000000
# mean     1860.008490    1929.991000      69.982510
# std        98.999218     102.747544      16.458408
# min       -30.000000      29.000000       1.000000
# 25%      1839.000000    1906.000000      61.000000
# 50%      1888.000000    1958.000000      73.000000
# 75%      1918.000000    1995.000000      82.000000
# max      2016.000000    2021.000000     119.000000
#                 Id                      Name  \
# 1000000  Q23926377            Pierre Merlier
# 1000001  Q23926378    Jacques Richard-Molard
# 1000002  Q23926380  Samuel-Sigismond Schwarz
# 1000003  Q23926385          Cyril Constantin
# 1000004  Q23926387          Théodore Tuffier
#
#                                          Short description Gender Country  \
# 1000000                                     French painter   Male  France
# 1000001                                  French geographer   Male  France
# 1000002               éditeur français d'origine hongroise   Male  France
# 1000003                                     French painter   Male  France
# 1000004  chirurgien français, pionnier de la chirurgie ...   Male  France
#
#              Occupation  Birth year  Death year Manner of death  Age of death
# 1000000          Artist        1931      2017.0  natural causes          86.0
# 1000001      Geographer        1913      1951.0  natural causes          38.0
# 1000002  Businessperson        1858      1932.0  natural causes          74.0
# 1000003          Artist        1904      1995.0  natural causes          91.0
# 1000004      Politician        1857      1929.0  natural causes          72.0
# Id                    object
# Name                  object
# Short description     object
# Gender                object
# Country               object
# Occupation            object
# Birth year             int64
# Death year           float64
# Manner of death       object
# Age of death         float64
# dtype: object
# Exploratory Data Analysis for Chunk 12:
#           Birth year     Death year   Age of death
# count  100000.000000  100000.000000  100000.000000
# mean     1831.232190    1899.002330      67.770140
# std       103.024114     107.547732      16.492894
# min       250.000000     301.000000       1.000000
# 25%      1794.000000    1858.000000      58.000000
# 50%      1860.000000    1927.000000      70.000000
# 75%      1903.000000    1977.000000      80.000000
# max      2016.000000    2021.000000     127.000000
#                 Id                  Name                Short description  \
# 1100000  Q52150746         Joseph Gajard              American politician
# 1100001  Q52150750       Alfred Moitroux                  Belgian painter
# 1100002  Q52150752           Dorothy Kay  Irish-born South African artist
# 1100003  Q52150755  John Young Johnstone                 Canadian painter
# 1100004  Q52150756  Alexander Warshawsky                 American painter
#
#          Gender                   Country Occupation  Birth year  Death year  \
# 1100000    Male  United States of America     Artist        1885      1972.0
# 1100001    Male                   Belgium     Artist        1886      1938.0
# 1100002  Female     Ireland; South Africa     Artist        1886      1964.0
# 1100003    Male                    Canada     Artist        1887      1930.0
# 1100004    Male  United States of America     Artist        1887      1945.0
#
#         Manner of death  Age of death
# 1100000  natural causes          87.0
# 1100001  natural causes          52.0
# 1100002  natural causes          78.0
# 1100003  natural causes          43.0
# 1100004  natural causes          58.0
# Id                    object
# Name                  object
# Short description     object
# Gender                object
# Country               object
# Occupation            object
# Birth year             int64
# Death year           float64
# Manner of death       object
# Age of death         float64
# dtype: object
# Exploratory Data Analysis for Chunk 13:
#          Birth year    Death year  Age of death
# count  22769.000000  22769.000000  22769.000000
# mean    1832.870174   1900.472485     67.602310
# std      106.983510    111.332405     17.902099
# min      300.000000    366.000000      1.000000
# 25%     1794.000000   1855.000000     58.000000
# 50%     1863.000000   1929.000000     71.000000
# 75%     1908.000000   1981.000000     81.000000
# max     2000.000000   2021.000000    116.000000
#                 Id                                             Name  \
# 1200000  Q64747043                               Luis Tola y Avilés
# 1200001  Q64747044                      Francesco Maria della Marra
# 1200002  Q64747047                         Francesco Antonio Depace
# 1200003  Q64747048                              Giambattista Donati
# 1200004  Q64747050  Jean-Marie Michel Arthur Alix Zacharie Raimbaud
#
#              Short description Gender                   Country  \
# 1200000  roman-catholic bishop   Male  United States of America
# 1200001  roman-catholic bishop   Male  United States of America
# 1200002  roman-catholic bishop   Male  United States of America
# 1200003  roman-catholic bishop   Male  United States of America
# 1200004  roman-catholic bishop   Male  United States of America
#
#                Occupation  Birth year  Death year Manner of death  \
# 1200000  Religious figure        1811      1888.0  natural causes
# 1200001  Religious figure        1582      1625.0  natural causes
# 1200002  Religious figure        1586      1655.0  natural causes
# 1200003  Religious figure        1715      1792.0  natural causes
# 1200004  Religious figure        1924      1989.0  natural causes
#
#          Age of death
# 1200000          77.0
# 1200001          43.0
# 1200002          69.0
# 1200003          77.0
# 1200004          65.0
# Id                    object
# Name                  object
# Short description     object
# Gender                object
# Country               object
# Occupation            object
# Birth year             int64
# Death year           float64
# Manner of death       object
# Age of death         float64
# dtype: object

# %% [markdown]
# ---

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# Perform the following EDA tasks using big data tools:
#
# a. Summary Statistics: Compute basic statistics such as mean, median, standard deviation, and quantiles for relevant numerical variables.
#
# b. Data Visualization: Create visualizations like histograms, box plots, scatter plots, and heatmaps to understand data distributions, correlations, and outliers.
#
# c. Data Exploration: Explore the dataset's structure and identify any patterns, trends, or anomalies. Pay attention to variables' distributions, relationships, and potential insights.
#
# d. Feature Engineering: If applicable, create new features or transform existing ones to better support your analysis.

# %% [markdown]
# ---

# %% [markdown]
# ### a. Summary Statistics
#
# Compute basic statistics such as mean, median, standard deviation, and quantiles for relevant numerical variables.

# %% [markdown]
# 1. Import pandas library

# %%
import pandas as pd

# %% [markdown]
# 2. Import dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/My Drive/Cleaned_AgeDataset_SYN.csv")
df
# Out:
#                 Id                     Name  \
# 0              Q23        George Washington
# 1              Q42            Douglas Adams
# 2              Q91          Abraham Lincoln
# 3             Q254  Wolfgang Amadeus Mozart
# 4             Q255     Ludwig van Beethoven
# ...            ...                      ...
# 1222764  Q77247326    Marie-Fortunée Besson
# 1222765  Q77249504              Ron Thorsen
# 1222766  Q77249818       Diether Todenhagen
# 1222767  Q77253909  Reginald Oswald Pearson
# 1222768  Q77254864             Horst Lerche
#
#                                          Short description Gender  \
# 0           1st president of the United States (1732–1799)   Male
# 1                              English writer and humorist   Male
# 2          16th president of the United States (1809-1865)   Male
# 3                Austrian composer of the Classical period   Male
# 4                   German classical and romantic composer   Male
# ...                                                    ...    ...
# 1222764                            Frans model (1907-1996)   Male
# 1222765        xugador de baloncestu canadianu (1948–2004)   Male
# 1222766  German navy officer and world war II U-boat co...   Male
# 1222767  English artist, working in stained glass, prin...   Male
# 1222768                                     German painter   Male
#
#                                                    Country  \
# 0        United States of America; Kingdom of Great Bri...
# 1                                           United Kingdom
# 2                                 United States of America
# 3          Archduchy of Austria; Archbishopric of Salzburg
# 4                       Holy Roman Empire; Austrian Empire
# ...                                                    ...
# 1222764                                             France
# 1222765                   Canada; United States of America
# 1222766                                            Germany
# 1222767                                     United Kingdom
# 1222768                                            Germany
#
#                  Occupation  Birth year  Death year Manner of death  \
# 0                Politician        1732      1799.0  natural causes
# 1                    Artist        1952      2001.0  natural causes
# 2                Politician        1809      1865.0        homicide
# 3                    Artist        1756      1791.0  natural causes
# 4                    Artist        1770      1827.0  natural causes
# ...                     ...         ...         ...             ...
# 1222764       Tailor; model        1907      1996.0  natural causes
# 1222765             Athlete        1948      2004.0  natural causes
# 1222766  Military personnel        1920      1944.0  natural causes
# 1222767              Artist        1887      1915.0  natural causes
# 1222768              Artist        1938      2017.0  natural causes
#
#          Age of death
# 0                67.0
# 1                49.0
# 2                56.0
# 3                35.0
# 4                57.0
# ...               ...
# 1222764          89.0
# 1222765          56.0
# 1222766          24.0
# 1222767          28.0
# 1222768          79.0
#
# [1222769 rows x 10 columns]

# %% [markdown]
# 3. Extract the 'Age of Death' column

# %%
age_of_death_column = df['Age of death']

# %% [markdown]
# 4. Compute basic statistics

# %% [markdown]
# > Mean

# %%
mean_age = age_of_death_column.mean()

# %%
print(f"Mean: {mean_age}")
# Out:
# Mean: 69.2875457261347

# %% [markdown]
# > Median

# %%
median_age = age_of_death_column.median()

# %%
print(f"Median: {median_age}")
# Out:
# Median: 72.0

# %% [markdown]
# > Standard deviation

# %%
std_dev_age = age_of_death_column.std()

# %%
print(f"Standard Deviation: {std_dev_age}")
# Out:
# Standard Deviation: 16.60288778121744

# %% [markdown]
# > 25th Quantiles

# %%
quantile_25_age = age_of_death_column.quantile(0.25)

# %%
print(f"25th Percentile: {quantile_25_age}")
# Out:
# 25th Percentile: 60.0

# %% [markdown]
# > 75th Quatiles

# %%
quantile_75_age = age_of_death_column.quantile(0.75)

# %%
print(f"75th Percentile: {quantile_75_age}")
# Out:
# 75th Percentile: 81.0

# %% [markdown]
# To perform an Exploratory Data Analysis (EDA) on this dataset, we'll use Python with the pandas library for data manipulation and analysis.
#
# **Tools and Libraries Used:**
#
# 1. **Python:** A versatile programming language.
# 2. **Pandas:** A powerful data manipulation library.
#
# **Steps Taken:**
#
# 1. **Data Loading:** Loaded the dataset using the pandas.read_csv() function.
# 2. **Overview of the Dataset:** Checked the structure of the dataset using df.head() to view the first few rows.
# 3. **Key Findings and Insights:** The summary statistics (mean, median, standard deviation, quantiles) offer numerical insights into the central tendency and spread of the "Age of Death" column.

# %% [markdown]
# ---

# %% [markdown]
# ### b. Data Visualization
# Create visualizations like histograms, box plots, scatter plots, and heatmaps to understand data distributions, correlations, and outliers.

# %% [markdown]
# 1. Import neccessary libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 2. From the Summary Statistics above, create a visualisation to understand data distributions.

# %%
# Extract the 'Age of Death' column
age_of_death_column = df['Age of death']

# %%
# Set the style for seaborn
sns.set(style="whitegrid")

# %%
# Visualize data distribution using a histogram
plt.figure(figsize=(10, 6))
sns.histplot(age_of_death_column, bins=30, kde=True, color='skyblue', edgecolor='black')
plt.title('Histogram of Age of Death')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# Visual explanation
# - The histogram for the 'Age of Death' dataset visually displays the distribution of ages. The X-axis represents age ranges, the Y-axis shows the frequency of individuals in each range, and bars depict the count within specific age intervals. The shape indicates the distribution's symmetry or skewness, and the central peak denotes the most common age of death.

# %%
# Visualize data distribution using a box plot
plt.figure(figsize=(8, 6))
sns.boxplot(x=age_of_death_column, color='lightcoral')
plt.title('Box Plot of Age of Death')
plt.xlabel('Age')
plt.show()

# %% [markdown]
# Visualisation explanation:
# - The box plot offers a concise summary of the distribution of the 'Age of Death' dataset. The central box represents the interquartile range (IQR), spanning from the 25th to the 75th percentiles, with the median marked by a line inside the box. The whiskers extend to the minimum and maximum values within a set range, typically 1.5 times the IQR. Outliers, presented as individual points beyond the whiskers, are easily identified.

# %% [markdown]
# 3. From the Summary Statistics above, create a visualisation to understand data correlations.

# %%
# Create a correlation matrix
correlation_matrix = df.corr()

plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()
# Out:
# <ipython-input-20-54cf538805ba>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()

# %% [markdown]
# Visual explanation
# - The heatmap visually represents the correlation of the 'Age of Death' column with itself. The diagonal line is uniformly red, indicating a perfect correlation (1.0) as expected for any variable correlated with itself. The heatmap provides a concise and immediate confirmation of the high correlation within the dataset.

# %%
# Plot a pair plot for Age of Death
plt.figure(figsize=(10, 8))
sns.pairplot(df)
plt.suptitle('Pair Plot for Age of Death', y=1.02)
plt.show()

# %% [markdown]
# Visual explanation:
# - The pair plot visually summarizes the 'Age of Death' dataset, displaying histograms along the diagonal for individual variable distributions and scatter plots below and above the diagonal, indicating the correlation of the variable with itself. In this specific case, it reaffirms the perfect positive correlation of the 'Age of Death' variable with itself.

# %% [markdown]
# ---

# %% [markdown]
# ### c. Data Exploration
#
# Explore the dataset's structure and identify any patterns, trends, or anomalies. Pay attention to variables' distributions, relationships, and potential insights.

# %% [markdown]
# Overview of dataset
#
# - First, let see the overview of the dataset. We need to hceck the first few rows of the dataset to understand its structure.

# %%
print(df.head())
# Out:
#      Id                     Name  \
# 0   Q23        George Washington
# 1   Q42            Douglas Adams
# 2   Q91          Abraham Lincoln
# 3  Q254  Wolfgang Amadeus Mozart
# 4  Q255     Ludwig van Beethoven
#
#                                  Short description Gender  \
# 0   1st president of the United States (1732–1799)   Male
# 1                      English writer and humorist   Male
# 2  16th president of the United States (1809-1865)   Male
# 3        Austrian composer of the Classical period   Male
# 4           German classical and romantic composer   Male
#
#                                              Country  Occupation  Birth year  \
# 0  United States of America; Kingdom of Great Bri...  Politician        1732
# 1                                     United Kingdom      Artist        1952
# 2                           United States of America  Politician        1809
# 3    Archduchy of Austria; Archbishopric of Salzburg      Artist        1756
# 4                 Holy Roman Empire; Austrian Empire      Artist        1770
#
#    Death year Manner of death  Age of death
# 0        1799  natural causes            67
# 1        2001  natural causes            49
# 2        1865        homicide            56
# 3        1791  natural causes            35
# 4        1827  natural causes            57

# %% [markdown]
# ---

# %% [markdown]
# Summary Statistics
#
# - Obtain summary statistics for numerical columns.

# %%
print(df.describe())
# Out:
#          Birth year    Death year  Age of death
# count  1.222769e+06  1.222769e+06  1.222769e+06
# mean   1.844990e+03  1.914278e+03  6.928755e+01
# std    1.479136e+02  1.516542e+02  1.660289e+01
# min   -2.700000e+03 -2.660000e+03  1.000000e+00
# 25%    1.828000e+03  1.895000e+03  6.000000e+01
# 50%    1.887000e+03  1.955000e+03  7.200000e+01
# 75%    1.918000e+03  1.994000e+03  8.100000e+01
# max    2.016000e+03  2.021000e+03  1.690000e+02

# %% [markdown]
# Age of Death Distribution by Gender:
#
# - Explore how the age of death varies between different genders.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Identify the top 5 ages of death for each gender
top5_age_death_male = df[df['Gender'] == 'Male']['Age of death'].value_counts().nlargest(5).index
top5_age_death_female = df[df['Gender'] == 'Female']['Age of death'].value_counts().nlargest(5).index

# Filter the DataFrame for the top 5 ages of death for each gender
df_top5_male = df[(df['Gender'] == 'Male') & (df['Age of death'].isin(top5_age_death_male))]
df_top5_female = df[(df['Gender'] == 'Female') & (df['Age of death'].isin(top5_age_death_female))]

# Combine the filtered DataFrames
df_top5 = pd.concat([df_top5_male, df_top5_female])

# Plot the box plot for the top 5 ages of death for each gender
plt.figure(figsize=(12, 8))
ax = sns.boxplot(x='Gender', y='Age of death', data=df_top5, palette='pastel')
plt.title('Box Plot: Top 5 Ages of Death by Gender')
plt.xlabel('Gender')
plt.ylabel('Age of Death')

# Add values beside the boxes
for i, box in enumerate(ax.artists):
    box_x = box.get_xdata()
    box_y = box.get_ydata()
    median_val = df_top5[df_top5['Gender'] == ax.get_xticklabels()[i].get_text()]['Age of death'].median()
    ax.text(box_x[0] + 0.5, box_y.mean(), f'Median: {median_val:.2f}',
            ha='center', va='center', color='black', fontweight='bold')

plt.show()

# %% [markdown]
# **Visual Explanation**
#
# In the boxplot, the age of death for men tends to occur at an earlier range, typically between 74 and 80 years old. In contrast, women exhibit a slightly later age of death, typically falling within the range of 82 to 88 years old.

# %% [markdown]
# Manner of Death Analysis:
#
# - Explore the distribution of the 'Manner of death' variable.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Identify the top 5 manners of death
top5_manner_of_death = df['Manner of death'].value_counts().nlargest(5).index

# Filter the DataFrame for the top 5 manners of death
df_top5_manner = df[df['Manner of death'].isin(top5_manner_of_death)]

# Plot the countplot for the top 5 manners of death
plt.figure(figsize=(12, 8))
ax = sns.countplot(x='Manner of death', data=df_top5_manner, palette='Set2')
plt.title('Top 5 Manners of Death')
plt.xlabel('Manner of Death')
plt.ylabel('Count')

# Add values on top of the bars
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', (p.get_x() + p.get_width() / 2., p.get_height()),
                ha='center', va='center', xytext=(0, 10), textcoords='offset points')

plt.show()

# %% [markdown]
# **Visual Explanation**
#
# The highest manner of death is natural causes with 120270 followed by suicide with 5814 and accident with 5044.

# %% [markdown]
# Country-wise Analysis:
#
# - Explore the distribution of deaths across different countries.

# %%
plt.figure(figsize=(12, 8))

# Identify the top 10 countries
top10_countries = df['Country'].value_counts().nlargest(10).index

# Filter the DataFrame for the top 10 countries
df_top10_countries = df[df['Country'].isin(top10_countries)]

# Plot the countplot for the top 10 countries
sns.countplot(x='Country', data=df_top10_countries, order=df_top10_countries['Country'].value_counts().index, palette='viridis')

plt.title('Top 10 Countries and Distribution of Deaths')
plt.xlabel('Country')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.show()

# %% [markdown]
# **Visual Explanation**
#
# - This code first identifies the top 10 countries, then filters the DataFrame accordingly, and finally plots the countplot for the distribution of deaths by country, considering only the top 10 countries
#
# - The highest of death happen at USA followed by Germany and France.

# %% [markdown]
# Birth Year vs. Age of Death Trend:
#
# - Explore the trend of age of death over the years.

# %%
plt.figure(figsize=(12, 8))

# Filter the DataFrame for the years 1990 until 2005
df_filtered = df[(df['Birth year'] >= 1990) & (df['Birth year'] <= 2005)]

# Plot the lineplot for the filtered data
sns.lineplot(x='Birth year', y='Age of death', data=df_filtered, ci=None, color='orange')

plt.title('Birth Year vs. Age of Death Trend (1990-2005)')
plt.xlabel('Birth Year')
plt.ylabel('Age of Death')
plt.show()
# Out:
# <ipython-input-46-36f85035ec2f>:7: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(x='Birth year', y='Age of death', data=df_filtered, ci=None, color='orange')

# %% [markdown]
# **Visual Explanation**
#
# In the line graph, there is an inverse relationship observed between birth year and age of death. Specifically, as the birth year increases, indicating more recent birth cohorts, there is a tendency for the age of death to decrease, suggesting a pattern where individuals from more recent birth years tend to have a lower age at the time of death.

# %% [markdown]
# Occupation Distribution:
#
# - Explore the distribution of deaths across different occupations.

# %%
plt.figure(figsize=(14, 8))

# Identify the top 10 occupations
top10_occupations = df['Occupation'].value_counts().nlargest(10).index

# Filter the DataFrame for the top 10 occupations
df_top10_occupations = df[df['Occupation'].isin(top10_occupations)]

# Identify the top 5 manners of death
top5_manners_of_death = df_top10_occupations['Manner of death'].value_counts().nlargest(5).index

# Filter the DataFrame for the top 5 manners of death within the top 10 occupations
df_top5_manners_of_death = df_top10_occupations[df_top10_occupations['Manner of death'].isin(top5_manners_of_death)]

# Plot the countplot for the top 10 occupations with 'Manner of death' as hue, considering only the top 5 manners
sns.countplot(x='Occupation', data=df_top5_manners_of_death,
              order=df_top10_occupations['Occupation'].value_counts().index,
              hue='Manner of death', palette='muted')

plt.title('Top 10 Occupations and Distribution of Deaths by Top 5 Manners of Death')
plt.xlabel('Occupation')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Manner of Death', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %% [markdown]
# **Visual Explanation**
#
# The highest occupation of this popular people is artist and the death of manner is natural causes. Occupation play a significant role of the manner of death.

# %% [markdown]
# ### d. Feature Engineering
#
# If applicable, create new features or transform existing ones to better support your analysis.

# %% [markdown]
# - We need to mounted the Google Drive. It establishes a connection between your Colab environment and Google Drive, enabling easy access to files and data stored in your Google Drive within the Colab notebook.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# - Once you've identified the path to your dataset, you can use pandas to read the data into a DataFrame. For example, reading a CSV file

# %%
df = pd.read_csv("drive/MyDrive/Cleaned_AgeDataset_SYN.csv")

# %% [markdown]
# - After that, we display the type of each dataset

# %%
import pandas as pd

# Convert 'Death year' from float to int
df['Death year'] = df['Death year'].astype(int)

# Convert 'Age of death' from float to int
df['Age of death'] = df['Age of death'].astype(int)

# Display the updated data types
print(df.dtypes)
# Out:
# Id                   object
# Name                 object
# Short description    object
# Gender               object
# Country              object
# Occupation           object
# Birth year            int64
# Death year            int64
# Manner of death      object
# Age of death          int64
# dtype: object

# %% [markdown]
# Question: Can we create a feature to capture the time span between 'Birth year' and 'Death year'?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

cleaned_file_path = "/content/drive/MyDrive/Cleaned_AgeDataset_SYN.csv"

# Chunk size
chunk_size = 100000  # Adjust this value based on your preferences

# Lists to accumulate life span values from all chunks
all_life_span_values = []

# Read the CSV file in chunks
for i, chunk in enumerate(pd.read_csv(cleaned_file_path, chunksize=chunk_size)):
    # Process each chunk as needed
    # For example, calculate 'Life Span' for each chunk
    chunk['Life Span'] = chunk['Death year'] - chunk['Birth year']

    # Plot histogram for each chunk
    plt.figure(figsize=(10, 8))
    sns.histplot(chunk['Life Span'].dropna(), bins=30, kde=True)
    plt.title(f'Distribution of Life Span - Chunk {i+1}')
    plt.show()

    # Accumulate life span values from each chunk
    all_life_span_values.extend(chunk['Life Span'].dropna().tolist())

    # Perform additional processing on each chunk if necessary

    # Save the chunk to a separate CSV file with 'Life Span' information
    chunk.to_csv(f"{cleaned_file_path}_chunk_{i+1}.csv", index=False)

# Plot the histogram for all accumulated life span values
plt.figure(figsize=(10, 8))
sns.histplot(all_life_span_values, bins=30, kde=True)
plt.title('Distribution of Life Span - All Chunks')
plt.show()

# Calculate and display the average life span
average_life_span = sum(all_life_span_values) / len(all_life_span_values)
print(f'Average Life Span across all chunks: {average_life_span}')
# Out:
# Average Life Span across all chunks: 69.28749829280919

# %% [markdown]
# **Code Explanation**
#
# This code ensures that the 'Death year' and 'Age of death' columns in the DataFrame have integer data types rather than float data types. This can be useful for working with these columns in a more appropriate numerical format, especially if the fractional part of the float values is not relevant in this context.

# %% [markdown]
# **Visual Explanation**
#
# In the process of feature engineering, we computed the life span for each individual by subtracting the birth year from the death year. The resulting life span values provide insights into the overall age distribution within the dataset, revealing that the average life span observed is 69.28 or 70 years old. This suggests that a significant portion of individuals in the dataset lived up to the age of 70.

# %% [markdown]
# Question : What is the top 3 manners of death and it life span?

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

cleaned_file_path = "/content/drive/MyDrive/Cleaned_AgeDataset_SYN.csv"

# Chunk size
chunk_size = 100000  # Adjust this value based on your preferences

# Create an empty DataFrame to store aggregated data
combined_df = pd.DataFrame()

# Read the CSV file in chunks
for i, chunk in enumerate(pd.read_csv(cleaned_file_path, chunksize=chunk_size)):
    # Process each chunk as needed
    # For example, calculate 'Life Span' for each chunk
    chunk['Life Span'] = chunk['Death year'] - chunk['Birth year']

    # Append the chunk to the combined DataFrame
    combined_df = combined_df.append(chunk, ignore_index=True)

    # Perform additional processing on each chunk if necessary

    # Save the chunk to a separate CSV file with 'Life Span' information
    chunk.to_csv(f"{cleaned_file_path}_chunk_{i+1}.csv", index=False)

# 'Manner of death' is just a placeholder, and you may need to adjust it.
top_manners_of_death = combined_df['Manner of death'].value_counts().head(3).index

# Filter the combined DataFrame for the top three manners of death
combined_df_top_manners = combined_df[combined_df['Manner of death'].isin(top_manners_of_death)]

# Create a facet grid for the combined data
plt.figure(figsize=(12, 8))
g = sns.FacetGrid(combined_df_top_manners, col='Manner of death', height=6)
g.map(sns.histplot, 'Life Span', bins=30, kde=True)

# Set axis labels and titles
g.set_axis_labels('Life Span', 'Count')
g.set_titles(col_template="{col_name}")
plt.suptitle('Distribution of Life Span by Top Three Manners of Death (Combined)', y=1.02)
plt.show()
# Out:
# <ipython-input-26-1b530828d9ab>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df = combined_df.append(chunk, ignore_index=True)
# <ipython-input-26-1b530828d9ab>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df = combined_df.append(chunk, ignore_index=True)
# <ipython-input-26-1b530828d9ab>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df = combined_df.append(chunk, ignore_index=True)
# <ipython-input-26-1b530828d9ab>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df = combined_df.append(chunk, ignore_index=True)
# <ipython-input-26-1b530828d9ab>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df = combined_df.append(chunk, ignore_index=True)
# <ipython-input-26-1b530828d9ab>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df = combined_df.append(chunk, ignore_index=True)
# <ipython-input-26-1b530828d9ab>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df = combined_df.append(chunk, ignore_index=True)
# <ipython-input-26-1b530828d9ab>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df = combined_df.append(chunk, ignore_index=True)
# <ipython-input-26-1b530828d9ab>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df = combined_df.append(chunk, ignore_index=True)
# <ipython-input-26-1b530828d9ab>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df = combined_df.append(chunk, ignore_index=True)
# <ipython-input-26-1b530828d9ab>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df = combined_df.append(chunk, ignore_index=True)
# <ipython-input-26-1b530828d9ab>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df = combined_df.append(chunk, ignore_index=True)
# <ipython-input-26-1b530828d9ab>:20: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   combined_df = combined_df.append(chunk, ignore_index=True)

# %% [markdown]
# **Code Explanation**
#
# - Read the CSV file in chunks using pd.read_csv and process each chunk. In this example, it calculates the 'Life Span' for each row in the chunk, appends the chunk to combined_df, and saves the chunk to a separate CSV file.
#
# - We initializes a Seaborn FacetGrid, which is a grid of subplots based on the 'Manner of death' column. Each subplot will represent one of the top three manners of death.
#
# - This code is to maps histograms of the 'Life Span' column onto the FacetGrid. Each subplot will display the distribution of life spans for a specific manner of death, with specified histogram binning and a kernel density estimate (kde) overlay.

# %% [markdown]
# **Visual Explanation**
#
# - From the graph above, we can see that natural causes is the main reason of highest death at 75 years old compared to suicide and accident. Regarding the cause of death, the predominant manner is identified as 'natural causes.'
#
# - A 'natural' death is characterized by internal factors leading to the cessation of vital functions, such as cancer, heart disease, or diabetes. Notably, instances of death attributed to suicide or accidents are relatively infrequent.

# %% [markdown]
# Question: How can we represent the diversity of top 5 'Occupation' within each 'Country'?

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

cleaned_file_path = "/content/drive/MyDrive/Cleaned_AgeDataset_SYN.csv"

# Chunk size
chunk_size = 100000  # Adjust this value based on your preferences

# Lists to accumulate chunks
all_chunks = []

# Read the CSV file in chunks
for i, chunk in enumerate(pd.read_csv(cleaned_file_path, chunksize=chunk_size)):
    # Perform additional processing on each chunk if necessary

    # Feature Engineering on each chunk
    chunk['Occupation Diversity'] = chunk.groupby('Country')['Occupation'].transform('nunique')

    # Append the chunk to the list
    all_chunks.append(chunk)

    # Save the chunk to a separate CSV file if needed
    chunk.to_csv(f"{cleaned_file_path}_chunk_{i+1}.csv", index=False)

# Combine all chunks into a single DataFrame
df_combined = pd.concat(all_chunks, ignore_index=True)

# Create a pivot table to summarize occupation diversity by country
occupation_diversity_table = pd.pivot_table(df_combined, values='Occupation Diversity', index='Country', aggfunc='mean')

# Get the top 5 countries by occupation diversity
top_countries = occupation_diversity_table.nlargest(5, 'Occupation Diversity')

# Display the table for the top 5 countries
print(top_countries)
# Out:
#                           Occupation Diversity
# Country
# United States of America            888.779041
# France                              420.680460
# Germany                             405.629157
# United Kingdom                      179.149480
# Japan                               178.678295

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

cleaned_file_path = "/content/drive/MyDrive/Cleaned_AgeDataset_SYN.csv"

# Chunk size
chunk_size = 100000  # Adjust this value based on your preferences

# Lists to accumulate chunks
all_chunks = []

# Read the CSV file in chunks
for i, chunk in enumerate(pd.read_csv(cleaned_file_path, chunksize=chunk_size)):
    # Perform additional processing on each chunk if necessary

    # Feature Engineering on each chunk
    chunk['Occupation Diversity'] = chunk.groupby('Country')['Occupation'].transform('nunique')

    # Append the chunk to the list
    all_chunks.append(chunk)

    # Save the chunk to a separate CSV file if needed
    chunk.to_csv(f"{cleaned_file_path}_chunk_{i+1}.csv", index=False)

# Combine all chunks into a single DataFrame
df_combined = pd.concat(all_chunks, ignore_index=True)

# Feature Engineering on the combined DataFrame
df_combined['Occupation Diversity'] = df_combined.groupby('Country')['Occupation'].transform('nunique')

# Create a pivot table to summarize occupation diversity by country
occupation_diversity_table = pd.pivot_table(df_combined, values='Occupation Diversity', index='Country', aggfunc='mean')

# Get the top 5 countries by occupation diversity
top_countries = occupation_diversity_table.nlargest(5, 'Occupation Diversity')

# Create a bar plot with numbers above the bars
plt.figure(figsize=(10, 6))
barplot = sns.barplot(x=top_countries.index, y='Occupation Diversity', data=top_countries)

# Annotate each bar with its value
for index, value in enumerate(top_countries['Occupation Diversity']):
    barplot.text(index, value + 0.1, str(round(value, 2)), ha='center', va='bottom')

plt.title('Top 5 Countries by Occupation Diversity')
plt.xlabel('Country')
plt.ylabel('Occupation Diversity')
plt.show()

# %% [markdown]
# **Code Explanation**
#
# - This code creates a pivot table (occupation_diversity_table) using pandas' pivot_table function. The table summarizes the mean (average) value of 'Occupation Diversity' for each unique 'Country.'
#
# - It extracts the top 5 countries with the highest average occupation diversity from the pivot table.

# %% [markdown]
# **Visual Explanation**
#
# - Upon analyzing the dataset, it becomes evident that a substantial portion of the individuals predominantly worked in the United States. The dataset exhibits occupational diversity, with 4416 distinct occupations recorded, closely followed by France with 1610 occupations. This observation aligns well with the concept of the 'American Dream.'

# %% [markdown]
# Question: Can we create a binary feature indicating whether the person died at an older age than the average age of death in their 'Country'?

# %%
import pandas as pd

cleaned_file_path = "/content/drive/MyDrive/Cleaned_AgeDataset_SYN.csv"

# Chunk size
chunk_size = 100000  # Adjust this value based on your preferences

# Lists to accumulate chunks
all_chunks = []

# Read the CSV file in chunks
for i, chunk in enumerate(pd.read_csv(cleaned_file_path, chunksize=chunk_size)):
    # Perform additional processing on each chunk if necessary

    # Calculate the average age of death for each country in each chunk
    average_age_by_country_chunk = chunk.groupby('Country')['Age of death'].mean()

    # Merge the average age back into the original chunk
    chunk = pd.merge(chunk, average_age_by_country_chunk.rename('Average Age'), left_on='Country', right_index=True)

    # Create a binary feature indicating whether the person died at an older age than the average age of death in their country
    chunk['Older than Average Age'] = chunk['Age of death'] > chunk['Average Age']

    # Drop the 'Average Age' column if you don't need it in your final DataFrame
    chunk = chunk.drop('Average Age', axis=1)

    # Append the chunk to the list
    all_chunks.append(chunk)

    # Save the chunk to a separate CSV file if needed
    chunk.to_csv(f"{cleaned_file_path}_chunk_{i+1}.csv", index=False)

# Combine all chunks into a single DataFrame
df_combined = pd.concat(all_chunks, ignore_index=True)

# Display the updated DataFrame
df_combined.head()
# Out:
#         Id               Name  \
# 0      Q23  George Washington
# 1  Q143317    Henry Middleton
# 2  Q234952         Betsy Ross
# 3  Q328181       Lewis Morris
# 4  Q329870      Abraham Clark
#
#                                    Short description  Gender  \
# 0     1st president of the United States (1732–1799)    Male
# 1  Plantation owner and public official from Sout...    Male
# 2      person credited with making the American flag  Female
# 3  American landowner and developer from Morrisan...    Male
# 4                    American politician (1726-1794)    Male
#
#                                              Country        Occupation  \
# 0  United States of America; Kingdom of Great Bri...        Politician
# 1  United States of America; Kingdom of Great Bri...        Politician
# 2  United States of America; Kingdom of Great Bri...  Tailor; designer
# 3  United States of America; Kingdom of Great Bri...        Politician
# 4  United States of America; Kingdom of Great Bri...        Politician
#
#    Birth year  Death year Manner of death  Age of death  \
# 0        1732      1799.0  natural causes          67.0
# 1        1717      1784.0  natural causes          67.0
# 2        1752      1836.0  natural causes          84.0
# 3        1726      1798.0  natural causes          72.0
# 4        1726      1794.0  natural causes          68.0
#
#    Older than Average Age
# 0                    True
# 1                    True
# 2                    True
# 3                    True
# 4                    True

# %% [markdown]
# **Code Explanation**
#
# This code explain groups the DataFrame 'df' by the 'Country' column and calculates the mean (average) of the 'Age of death' column for each group (i.e., each country). The result is a Pandas Series where each country is associated with its average age of death.

# %% [markdown]
# **Visual Explanation**
#
# In summary, the "Older than Average Age" column is a binary feature that helps categorize individuals based on whether they died at an age above or below the average age of death in their respective countries. This can be useful for exploring patterns related to age and mortality in different geographic regions.

# %%
import pandas as pd

cleaned_file_path = "/content/drive/MyDrive/Cleaned_AgeDataset_SYN.csv"

# Chunk size
chunk_size = 100000  # Adjust this value based on your preferences

# Lists to accumulate chunks
all_chunks = []

# Read the CSV file in chunks
for i, chunk in enumerate(pd.read_csv(cleaned_file_path, chunksize=chunk_size)):
    # Perform additional processing on each chunk if necessary

    # Calculate the average age of death for each country in each chunk
    average_age_by_country_chunk = chunk.groupby('Country')['Age of death'].mean()

    # Merge the average age back into the original chunk
    chunk = pd.merge(chunk, average_age_by_country_chunk.rename('Average Age'), left_on='Country', right_index=True)

    # Create a binary feature indicating whether the person died at an older age than the average age of death in their country
    chunk['Older than Average Age'] = chunk['Age of death'] > chunk['Average Age']

    # Append the chunk to the list
    all_chunks.append(chunk)

    # Save the chunk to a separate CSV file if needed
    chunk.to_csv(f"{cleaned_file_path}_chunk_{i+1}.csv", index=False)

# Combine all chunks into a single DataFrame
df_combined = pd.concat(all_chunks, ignore_index=True)

# Count the number of people who died at an older age than the average age and those with age less than or equal to the average age
age_comparison_counts_combined = df_combined['Older than Average Age'].value_counts()

# Display the counts
print("Number of people who died at an older age than the average age:")
print(age_comparison_counts_combined[True])

print("\nNumber of people with age less than or equal to the average age:")
print(age_comparison_counts_combined[False])

# Drop the 'Average Age' column if you don't need it in your final DataFrame
df_combined = df_combined.drop('Average Age', axis=1)

# Display the updated DataFrame
df_combined.head()
# Out:
# Number of people who died at an older age than the average age:
# 682020
#
# Number of people with age less than or equal to the average age:
# 540749
#         Id               Name  \
# 0      Q23  George Washington
# 1  Q143317    Henry Middleton
# 2  Q234952         Betsy Ross
# 3  Q328181       Lewis Morris
# 4  Q329870      Abraham Clark
#
#                                    Short description  Gender  \
# 0     1st president of the United States (1732–1799)    Male
# 1  Plantation owner and public official from Sout...    Male
# 2      person credited with making the American flag  Female
# 3  American landowner and developer from Morrisan...    Male
# 4                    American politician (1726-1794)    Male
#
#                                              Country        Occupation  \
# 0  United States of America; Kingdom of Great Bri...        Politician
# 1  United States of America; Kingdom of Great Bri...        Politician
# 2  United States of America; Kingdom of Great Bri...  Tailor; designer
# 3  United States of America; Kingdom of Great Bri...        Politician
# 4  United States of America; Kingdom of Great Bri...        Politician
#
#    Birth year  Death year Manner of death  Age of death  \
# 0        1732      1799.0  natural causes          67.0
# 1        1717      1784.0  natural causes          67.0
# 2        1752      1836.0  natural causes          84.0
# 3        1726      1798.0  natural causes          72.0
# 4        1726      1794.0  natural causes          68.0
#
#    Older than Average Age
# 0                    True
# 1                    True
# 2                    True
# 3                    True
# 4                    True

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

cleaned_file_path = "/content/drive/MyDrive/Cleaned_AgeDataset_SYN.csv"

# Chunk size
chunk_size = 100000  # Adjust this value based on your preferences

# Lists to accumulate chunks
all_chunks = []

# Read the CSV file in chunks
for i, chunk in enumerate(pd.read_csv(cleaned_file_path, chunksize=chunk_size)):
    # Perform additional processing on each chunk if necessary

    # Calculate the average age of death for each country in each chunk
    average_age_by_country_chunk = chunk.groupby('Country')['Age of death'].mean()

    # Merge the average age back into the original chunk
    chunk = pd.merge(chunk, average_age_by_country_chunk.rename('Average Age'), left_on='Country', right_index=True)

    # Create a binary feature indicating whether the person died at an older age than the average age of death in their country
    chunk['Older than Average Age'] = chunk['Age of death'] > chunk['Average Age']

    # Append the chunk to the list
    all_chunks.append(chunk)

    # Save the chunk to a separate CSV file if needed
    chunk.to_csv(f"{cleaned_file_path}_chunk_{i+1}.csv", index=False)

# Combine all chunks into a single DataFrame
df_combined = pd.concat(all_chunks, ignore_index=True)

# Count the number of people who died at an older age than the average age and those with age less than or equal to the average age
age_comparison_counts_combined = df_combined['Older than Average Age'].value_counts()

# Plot a bar graph with total numbers on top of each bar
plt.figure(figsize=(8, 6))
ax = sns.barplot(x=age_comparison_counts_combined.index, y=age_comparison_counts_combined.values)

# Add total numbers on top of each bar
for i, value in enumerate(age_comparison_counts_combined.values):
    ax.text(i, value + 0.1, str(value), ha='center', va='bottom')

plt.title('Number of People by Age Comparison')
plt.xlabel('Age Comparison')
plt.ylabel('Count')
plt.xticks([0, 1], ['Older than Average Age', 'Less than or Equal to Average Age'])
plt.show()

# Drop the 'Average Age' column if you don't need it in your final DataFrame
df_combined = df_combined.drop('Average Age', axis=1)

# Display the updated DataFrame
df_combined.head()
# Out:
#         Id               Name  \
# 0      Q23  George Washington
# 1  Q143317    Henry Middleton
# 2  Q234952         Betsy Ross
# 3  Q328181       Lewis Morris
# 4  Q329870      Abraham Clark
#
#                                    Short description  Gender  \
# 0     1st president of the United States (1732–1799)    Male
# 1  Plantation owner and public official from Sout...    Male
# 2      person credited with making the American flag  Female
# 3  American landowner and developer from Morrisan...    Male
# 4                    American politician (1726-1794)    Male
#
#                                              Country        Occupation  \
# 0  United States of America; Kingdom of Great Bri...        Politician
# 1  United States of America; Kingdom of Great Bri...        Politician
# 2  United States of America; Kingdom of Great Bri...  Tailor; designer
# 3  United States of America; Kingdom of Great Bri...        Politician
# 4  United States of America; Kingdom of Great Bri...        Politician
#
#    Birth year  Death year Manner of death  Age of death  \
# 0        1732      1799.0  natural causes          67.0
# 1        1717      1784.0  natural causes          67.0
# 2        1752      1836.0  natural causes          84.0
# 3        1726      1798.0  natural causes          72.0
# 4        1726      1794.0  natural causes          68.0
#
#    Older than Average Age
# 0                    True
# 1                    True
# 2                    True
# 3                    True
# 4                    True

# %% [markdown]
# **Code Explanation**
#
# This line calculates the average age of death for each country using the 'groupby' and 'mean' functions in Pandas. It creates a Pandas Series called 'average_age_by_country' where each country is associated with its average age of death.

# %% [markdown]
# **Visual Explanation**
#
# The final graphical representation illustrates a comparison between individuals who passed away at an age older than the average and those who died at an age less than or equal to the average death age. The data indicates that 682020 individuals fall into the former category, while 540749 individuals fall into the latter. This discrepancy can be attributed to various lifestyle factors influencing the longevity of individuals in the dataset.
