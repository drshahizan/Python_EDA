# %% [markdown]
# <a href="https://colab.research.google.com/github/drshahizan/Python_EDA/blob/main/assignment/hpdp/SYNA/casestudy1/SYNA_CASESTUDY1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 2
# #### Title : Vaccination of Covid-19 in school of Malaysia
# #### Group : SYNA
# #### Group Members
# #### 1. SARAH WARDINA BINTI RAFIDIN A21EC0128
# #### 2. NURUNNAJWA BINTI ZULKIFLI A21EC0121
# #### 3. ALYA DAMIA BINTI HUZAIMY A21EC0159
# #### 4. YASMEEN NATASHA BINTI HAFIZ SHAHREL A21EC0147

# %% [markdown]
# # CASE STUDY 1

# %% [markdown]
# ## Data Preparation and Cleansing

# %% [markdown]
# Instructions (delete this cell):
#
# - Load the dataset into a data frame using Pandas
# - Explore the number of rows & columns, ranges of values etc.
# - Handle missing, incorrect and invalid data
# - Perform any additional steps (parsing dates, creating additional columns, merging multiple dataset etc.)

# %% [markdown]
#  This data provides an overview and analysis of the COVID-19 vaccination data in Malaysian schools, specifically focusing on the dataset titled vax_school.csv. The dataset contains information on vaccination doses administered to staff, students, and various age groups within different schools across Malaysia.

# %% [markdown]
# 1. First, we import the necessary libraries

# %%
import pandas as pd

import numpy as np

import matplotlib.pyplot as plt

# %%
path = "https://raw.githubusercontent.com/MoH-Malaysia/covid19-public/main/vaccination/vax_school.csv"

# %%
vax = pd.read_csv(path)

# Display the DataFrame
vax
# Out:
#           code                school  state  district  postcode       lat  \
# 0      ABA0001  SK TOH TANDEWA SAKTI      8        56     35000  4.196633
# 1      ABA0002      SK PENDITA ZA'BA      8        56     35400  4.178276
# 2      ABA0003              SK BANIR      8        56     35400  4.204361
# 3      ABA0004              SK TEMOH      8        56     35350  4.235841
# 4      ABA0005        SK CHENDERIANG      8        56     35300  4.267980
# ...        ...                   ...    ...       ...       ...       ...
# 10211  YRA2201     SMK AGAMA SARATOK     13       126     95407  1.763628
# 10212  YRA3101    SMK AGAMA SIBU (S)     13       131     96000  2.337200
# 10213  YRA3201        SMK AGAMA IGAN     13       107     96400  2.824150
# 10214  YRA4101             SMK AGAMA     13       121     98000  4.298633
# 10215  YRA5101     SMK AGAMA LIMBANG     13       115     98700  4.684617
#
#               lon  dose1_staff  dose2_staff  dose3_staff  ...  dose2_9  \
# ...

# %% [markdown]
# 2. The dataset has been downloaded and extracted.

# %% [markdown]
# 3. Find info about this dataset

# %% [markdown]
# The dataset consists of 10,216 entries and 40 columns, capturing detailed information about vaccination activities in schools. Here is a summary of the key columns:
#
# - code: School codes for identification.
# - school: School names.
# - state, district, postcode: Geographic information of the schools.
# - lat, lon: Latitude and longitude coordinates of the schools.
# - dose1_staff, dose2_staff, dose3_staff: Vaccination doses administered to staff members.
# - dose1_student, dose2_student: Vaccination doses administered to students.
# - Columns from dose1_5 to dose2_18: Possible vaccination doses administered to different age groups, with varying levels of missing data.

# %%
vax.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10216 entries, 0 to 10215
# Data columns (total 40 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   code           10216 non-null  object
#  1   school         10216 non-null  object
#  2   state          10216 non-null  int64
#  3   district       10216 non-null  int64
#  4   postcode       10216 non-null  int64
#  5   lat            10216 non-null  float64
#  6   lon            10216 non-null  float64
#  7   dose1_staff    10212 non-null  float64
#  8   dose2_staff    10212 non-null  float64
#  9   dose3_staff    10212 non-null  float64
#  10  dose1_student  10174 non-null  float64
#  11  dose2_student  10174 non-null  float64
#  12  dose1_5        0 non-null      float64
#  13  dose1_6        0 non-null      float64
#  14  dose1_7        0 non-null      float64
#  15  dose1_8        0 non-null      float64
#  16  dose1_9        0 non-null      float64
# ...

# %% [markdown]
# 4. Above show the info of the dataset

# %% [markdown]
# 5. Next, drop column with all null values  which are dose1_5 to dose2_18

# %%
vax_cleaned = vax.dropna(axis=1, how='all')

# %%
vax_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10216 entries, 0 to 10215
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   code           10216 non-null  object
#  1   school         10216 non-null  object
#  2   state          10216 non-null  int64
#  3   district       10216 non-null  int64
#  4   postcode       10216 non-null  int64
#  5   lat            10216 non-null  float64
#  6   lon            10216 non-null  float64
#  7   dose1_staff    10212 non-null  float64
#  8   dose2_staff    10212 non-null  float64
#  9   dose3_staff    10212 non-null  float64
#  10  dose1_student  10174 non-null  float64
#  11  dose2_student  10174 non-null  float64
#  12  dose1_12       8526 non-null   float64
#  13  dose1_13       3552 non-null   float64
#  14  dose1_14       2976 non-null   float64
#  15  dose1_15       2552 non-null   float64
#  16  dose1_16       2414 non-null   float64
# ...

# %% [markdown]
# 6. Info above shows that column has reduce from 40 columns to 26 columns

# %% [markdown]
# 7. Fill missing values in specific columns with appropriate mean values

# %%
numerical_columns = vax_cleaned.select_dtypes(include=['float64']).columns
vax_cleaned[numerical_columns] = vax_cleaned[numerical_columns].fillna(vax_cleaned[numerical_columns].mean())
# Out:
# <ipython-input-8-a1a37cb6b63e>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   vax_cleaned[numerical_columns] = vax_cleaned[numerical_columns].fillna(vax_cleaned[numerical_columns].mean())

# %%
vax_cleaned.head()
# Out:
#       code                school  state  district  postcode       lat  \
# 0  ABA0001  SK TOH TANDEWA SAKTI      8        56     35000  4.196633
# 1  ABA0002      SK PENDITA ZA'BA      8        56     35400  4.178276
# 2  ABA0003              SK BANIR      8        56     35400  4.204361
# 3  ABA0004              SK TEMOH      8        56     35350  4.235841
# 4  ABA0005        SK CHENDERIANG      8        56     35300  4.267980
#
#           lon  dose1_staff  dose2_staff  dose3_staff  ...   dose1_16  \
# 0  101.255932        100.0        100.0         92.3  ...  98.119345
# 1  101.200617        100.0        100.0         81.6  ...  98.119345
# 2  101.181893        100.0        100.0         86.7  ...  98.119345
# 3  101.172819        100.0        100.0         77.3  ...  98.119345
# 4  101.240556        100.0        100.0         87.0  ...  98.119345
#
#     dose1_17   dose1_18  dose2_12    dose2_13   dose2_14   dose2_15  \
# ...

# %% [markdown]
# 8. The NaN value has changed to mean values

# %%
vax_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10216 entries, 0 to 10215
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   code           10216 non-null  object
#  1   school         10216 non-null  object
#  2   state          10216 non-null  int64
#  3   district       10216 non-null  int64
#  4   postcode       10216 non-null  int64
#  5   lat            10216 non-null  float64
#  6   lon            10216 non-null  float64
#  7   dose1_staff    10216 non-null  float64
#  8   dose2_staff    10216 non-null  float64
#  9   dose3_staff    10216 non-null  float64
#  10  dose1_student  10216 non-null  float64
#  11  dose2_student  10216 non-null  float64
#  12  dose1_12       10216 non-null  float64
#  13  dose1_13       10216 non-null  float64
#  14  dose1_14       10216 non-null  float64
#  15  dose1_15       10216 non-null  float64
#  16  dose1_16       10216 non-null  float64
# ...

# %% [markdown]
# 9. Find unique values in the 'school' column

# %%
unique_values = vax_cleaned.stack().unique()
unique_values
# Out:
# array(['ABA0001', 'SK TOH TANDEWA SAKTI', 8, ..., 'SMK AGAMA LIMBANG',
#        4.684616667, 115.0128333], dtype=object)

# %% [markdown]
# 10. Remove duplicate column in all columns

# %%
duplicate_rows = vax_cleaned.duplicated()

# %%
duplicates = vax_cleaned[duplicate_rows]
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [code, school, state, district, postcode, lat, lon, dose1_staff, dose2_staff, dose3_staff, dose1_student, dose2_student, dose1_12, dose1_13, dose1_14, dose1_15, dose1_16, dose1_17, dose1_18, dose2_12, dose2_13, dose2_14, dose2_15, dose2_16, dose2_17, dose2_18]
# Index: []
#
# [0 rows x 26 columns]

# %%
vax_cleaned = vax_cleaned.drop_duplicates()

# %%
vax_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 10216 entries, 0 to 10215
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   code           10216 non-null  object
#  1   school         10216 non-null  object
#  2   state          10216 non-null  int64
#  3   district       10216 non-null  int64
#  4   postcode       10216 non-null  int64
#  5   lat            10216 non-null  float64
#  6   lon            10216 non-null  float64
#  7   dose1_staff    10216 non-null  float64
#  8   dose2_staff    10216 non-null  float64
#  9   dose3_staff    10216 non-null  float64
#  10  dose1_student  10216 non-null  float64
#  11  dose2_student  10216 non-null  float64
#  12  dose1_12       10216 non-null  float64
#  13  dose1_13       10216 non-null  float64
#  14  dose1_14       10216 non-null  float64
#  15  dose1_15       10216 non-null  float64
#  16  dose1_16       10216 non-null  float64
# ...

# %% [markdown]
# 11. Info above shows there are no duplicate column and rows

# %% [markdown]
# 12. Reset index after dropping rows

# %%
vax_cleaned.reset_index(drop=True, inplace=True)

# %%
vax_cleaned.head()
# Out:
#       code                school  state  district  postcode       lat  \
# 0  ABA0001  SK TOH TANDEWA SAKTI      8        56     35000  4.196633
# 1  ABA0002      SK PENDITA ZA'BA      8        56     35400  4.178276
# 2  ABA0003              SK BANIR      8        56     35400  4.204361
# 3  ABA0004              SK TEMOH      8        56     35350  4.235841
# 4  ABA0005        SK CHENDERIANG      8        56     35300  4.267980
#
#           lon  dose1_staff  dose2_staff  dose3_staff  ...   dose1_16  \
# 0  101.255932        100.0        100.0         92.3  ...  98.119345
# 1  101.200617        100.0        100.0         81.6  ...  98.119345
# 2  101.181893        100.0        100.0         86.7  ...  98.119345
# 3  101.172819        100.0        100.0         77.3  ...  98.119345
# 4  101.240556        100.0        100.0         87.0  ...  98.119345
#
#     dose1_17   dose1_18  dose2_12    dose2_13   dose2_14   dose2_15  \
# ...

# %%
vax_cleaned.tail()
# Out:
#           code              school  state  district  postcode       lat  \
# 10211  YRA2201   SMK AGAMA SARATOK     13       126     95407  1.763628
# 10212  YRA3101  SMK AGAMA SIBU (S)     13       131     96000  2.337200
# 10213  YRA3201      SMK AGAMA IGAN     13       107     96400  2.824150
# 10214  YRA4101           SMK AGAMA     13       121     98000  4.298633
# 10215  YRA5101   SMK AGAMA LIMBANG     13       115     98700  4.684617
#
#               lon  dose1_staff  dose2_staff  dose3_staff  ...  dose1_16  \
# 10211  111.337767         98.5         98.5         92.4  ...     100.0
# 10212  111.840383        100.0        100.0         96.2  ...      97.2
# 10213  111.712617        100.0         98.3         88.3  ...      98.8
# 10214  113.955867        100.0        100.0         91.9  ...      98.0
# 10215  115.012833        100.0        100.0         89.2  ...      98.9
#
#        dose1_17  dose1_18    dose2_12  dose2_13  dose2_14  dose2_15  dose2_16  \
# ...

# %% [markdown]
# 13. Round all float columns to 2 decimal places

# %%
vax_cleaned = vax_cleaned.round(2)

# %%
vax_cleaned.head()
# Out:
#       code                school  state  district  postcode       lat  \
# 0  ABA0001  SK TOH TANDEWA SAKTI      8        56     35000  4.196633
# 1  ABA0002      SK PENDITA ZA'BA      8        56     35400  4.178276
# 2  ABA0003              SK BANIR      8        56     35400  4.204361
# 3  ABA0004              SK TEMOH      8        56     35350  4.235841
# 4  ABA0005        SK CHENDERIANG      8        56     35300  4.267980
#
#           lon  dose1_staff  dose2_staff  dose3_staff  ...   dose1_16  \
# 0  101.255932        100.0        100.0         92.3  ...  98.119345
# 1  101.200617        100.0        100.0         81.6  ...  98.119345
# 2  101.181893        100.0        100.0         86.7  ...  98.119345
# 3  101.172819        100.0        100.0         77.3  ...  98.119345
# 4  101.240556        100.0        100.0         87.0  ...  98.119345
#
#     dose1_17   dose1_18  dose2_12    dose2_13   dose2_14   dose2_15  \
# ...

# %%
vax_cleaned.tail()
# Out:
#           code              school  state  district  postcode       lat  \
# 10211  YRA2201   SMK AGAMA SARATOK     13       126     95407  1.763628
# 10212  YRA3101  SMK AGAMA SIBU (S)     13       131     96000  2.337200
# 10213  YRA3201      SMK AGAMA IGAN     13       107     96400  2.824150
# 10214  YRA4101           SMK AGAMA     13       121     98000  4.298633
# 10215  YRA5101   SMK AGAMA LIMBANG     13       115     98700  4.684617
#
#               lon  dose1_staff  dose2_staff  dose3_staff  ...  dose1_16  \
# 10211  111.337767         98.5         98.5         92.4  ...     100.0
# 10212  111.840383        100.0        100.0         96.2  ...      97.2
# 10213  111.712617        100.0         98.3         88.3  ...      98.8
# 10214  113.955867        100.0        100.0         91.9  ...      98.0
# 10215  115.012833        100.0        100.0         89.2  ...      98.9
#
#        dose1_17  dose1_18    dose2_12  dose2_13  dose2_14  dose2_15  dose2_16  \
# ...

# %% [markdown]
# 14. All the float data type column has set to two decimal places

# %% [markdown]
# 15. Change the data type of state and postcode into string

# %%
# Convert 'state' and 'district' columns to strings
vax_cleaned['state'] = vax_cleaned['state'].astype(str)
vax_cleaned['district'] = vax_cleaned['district'].astype(str)

# %%
vax_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10216 entries, 0 to 10215
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   code           10216 non-null  object
#  1   school         10216 non-null  object
#  2   state          10216 non-null  object
#  3   district       10216 non-null  object
#  4   postcode       10216 non-null  int64
#  5   lat            10216 non-null  float64
#  6   lon            10216 non-null  float64
#  7   dose1_staff    10216 non-null  float64
#  8   dose2_staff    10216 non-null  float64
#  9   dose3_staff    10216 non-null  float64
#  10  dose1_student  10216 non-null  float64
#  11  dose2_student  10216 non-null  float64
#  12  dose1_12       10216 non-null  float64
#  13  dose1_13       10216 non-null  float64
#  14  dose1_14       10216 non-null  float64
#  15  dose1_15       10216 non-null  float64
#  16  dose1_16       10216 non-null  float64
# ...

# %% [markdown]
# 16. State and district succeccfully changed to string data type

# %%
vax_cleaned.head()
# Out:
#       code                school state district  postcode       lat  \
# 0  ABA0001  SK TOH TANDEWA SAKTI     8       56     35000  4.196633
# 1  ABA0002      SK PENDITA ZA'BA     8       56     35400  4.178276
# 2  ABA0003              SK BANIR     8       56     35400  4.204361
# 3  ABA0004              SK TEMOH     8       56     35350  4.235841
# 4  ABA0005        SK CHENDERIANG     8       56     35300  4.267980
#
#           lon  dose1_staff  dose2_staff  dose3_staff  ...   dose1_16  \
# 0  101.255932        100.0        100.0         92.3  ...  98.119345
# 1  101.200617        100.0        100.0         81.6  ...  98.119345
# 2  101.181893        100.0        100.0         86.7  ...  98.119345
# 3  101.172819        100.0        100.0         77.3  ...  98.119345
# 4  101.240556        100.0        100.0         87.0  ...  98.119345
#
#     dose1_17   dose1_18  dose2_12    dose2_13   dose2_14   dose2_15  \
# 0  98.521671  98.141756      83.1  100.000000  100.00000  89.350705
# ...

# %%
vax_cleaned.tail()
# Out:
#           code              school state district  postcode       lat  \
# 10211  YRA2201   SMK AGAMA SARATOK    13      126     95407  1.763628
# 10212  YRA3101  SMK AGAMA SIBU (S)    13      131     96000  2.337200
# 10213  YRA3201      SMK AGAMA IGAN    13      107     96400  2.824150
# 10214  YRA4101           SMK AGAMA    13      121     98000  4.298633
# 10215  YRA5101   SMK AGAMA LIMBANG    13      115     98700  4.684617
#
#               lon  dose1_staff  dose2_staff  dose3_staff  ...  dose1_16  \
# 10211  111.337767         98.5         98.5         92.4  ...     100.0
# 10212  111.840383        100.0        100.0         96.2  ...      97.2
# 10213  111.712617        100.0         98.3         88.3  ...      98.8
# 10214  113.955867        100.0        100.0         91.9  ...      98.0
# 10215  115.012833        100.0        100.0         89.2  ...      98.9
#
#        dose1_17  dose1_18    dose2_12  dose2_13  dose2_14  dose2_15  dose2_16  \
# ...

# %%
vax_cleaned.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10216 entries, 0 to 10215
# Data columns (total 26 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   code           10216 non-null  object
#  1   school         10216 non-null  object
#  2   state          10216 non-null  object
#  3   district       10216 non-null  object
#  4   postcode       10216 non-null  int64
#  5   lat            10216 non-null  float64
#  6   lon            10216 non-null  float64
#  7   dose1_staff    10216 non-null  float64
#  8   dose2_staff    10216 non-null  float64
#  9   dose3_staff    10216 non-null  float64
#  10  dose1_student  10216 non-null  float64
#  11  dose2_student  10216 non-null  float64
#  12  dose1_12       10216 non-null  float64
#  13  dose1_13       10216 non-null  float64
#  14  dose1_14       10216 non-null  float64
#  15  dose1_15       10216 non-null  float64
#  16  dose1_16       10216 non-null  float64
# ...

# %% [markdown]
# 17. Dataset successfully prep and cleaned

# %% [markdown]
# ## Exploratory Analysis and Visualization

# %% [markdown]
# We are going to perform analysis and visualization of the dataset using libraries such as `matplotlib.byplot` and `seaborn`.

# %% [markdown]
# Let's begin by `importingmatplotlib.pyplot`, `numpy` and `seaborn`.

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (9, 5)
matplotlib.rcParams['figure.facecolor'] = '#00000000'

# %% [markdown]
# **TODO 1** - Find the `count` of dose 1 vaccination for staff.

# %%
import pandas as pd

# Load the dataset
data = pd.read_csv('https://raw.githubusercontent.com/MoH-Malaysia/covid19-public/main/vaccination/vax_school.csv')

# Find the count of dose 1 vaccination for staff
sns.histplot(data['dose1_staff'])
# Out:
# <Axes: xlabel='dose1_staff', ylabel='Count'>

# %% [markdown]
# Here we can see the statistical graphic in the form of `histogram` of count of dose 1 vaccination for staff by implementing `seaborn`.

# %% [markdown]
# **TODO 2** - Find the `count` of dose 2 vaccination for staff.

# %%
# Find the count of dose 2 vaccination for staff
sns.histplot(data['dose2_staff'])
# Out:
# <Axes: xlabel='dose2_staff', ylabel='Count'>

# %% [markdown]
# **TODO 3** - Find the `count` of dose 3 vaccination for staff.

# %%
# Find the count of dose 3 vaccination for staff
sns.histplot(data['dose3_staff'])
# Out:
# <Axes: xlabel='dose3_staff', ylabel='Count'>

# %% [markdown]
# **TODO 4** - Find the `mean` of dose 1 vaccination for staff.

# %%
# Calculate the mean using NumPy
mean_value = np.mean(data['dose1_staff'])

# Create a histogram using Seaborn
sns.histplot(data['dose1_staff'])

# Add a vertical line representing the mean using Matplotlib
plt.axvline(x=mean_value, color='red', linestyle='--', label=f'Mean: {mean_value: .2f}')

# Add labels and titles
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram with Mean Line')

# Show the plot
plt.legend()
plt.show()

# %% [markdown]
# Based on the graph, we find that the `mean` value for dose 1 vaccination for staff is **99.42**.

# %% [markdown]
# **TODO 5** - Find the `mean` of dose 2 vaccination for staff.

# %%
# Calculate the mean using NumPy
mean_value = np.mean(data['dose2_staff'])

# Create a histogram using Seaborn
sns.histplot(data['dose2_staff'])

# Add a vertical line representing the mean using Matplotlib
plt.axvline(x=mean_value, color='red', linestyle='--', label=f'Mean: {mean_value: .2f}')

# Add labels and titles
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram with Mean Line')

# Show the plot
plt.legend()
plt.show()

# %% [markdown]
# **TODO 6** - Find the `mean` of dose 3 vaccination for staff.

# %%
# Calculate the mean using NumPy
mean_value = np.mean(data['dose3_staff'])

# Create a histogram using Seaborn
sns.histplot(data['dose3_staff'])

# Add a vertical line representing the mean using Matplotlib
plt.axvline(x=mean_value, color='red', linestyle='--', label=f'Mean: {mean_value: .2f}')

# Add labels and titles
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.title('Histogram with Mean Line')

# Show the plot
plt.legend()
plt.show()

# %% [markdown]
# **TODO 7** - Find the `range` for postcode.

# %%
data_range_postcode = np.ptp(data['postcode'])
print(f"The range for the 'postcode' column is: {data_range_postcode}")
# Out:
# The range for the 'postcode' column is: 97850

# %%
sns.boxplot(x=data['postcode'])

# Add label and title
plt.xlabel('Postcode')
plt.title('Boxplot of Postcode Range')

# Show the plot
plt.show()

# %% [markdown]
# **TODO 8** - Create a scatter plot with the `dose1_staff` and `dose2_staff` columns.

# %%
sns.scatterplot(x=data['dose1_staff'], y=data['dose2_staff'])

# Add labels and title
plt.xlabel('Dose 1 Staff')
plt.ylabel('Dose 2 Staff')
plt.title('Scatter Plot of Dose 1 Staff vs Dose 2 Staff')

# Show the plot
plt.show()

# %% [markdown]
# **TODO 9** - Create a scatter plot with the `dose2_staff` and `dose3_staff` columns.

# %%
sns.scatterplot(x=data['dose2_staff'], y=data['dose3_staff'])

# Add labels and title
plt.xlabel('Dose 2 Staff')
plt.ylabel('Dose 3 Staff')
plt.title('Scatter Plot of Dose 2 Staff vs Dose 3 Staff')

# Show the plot
plt.show()

# %% [markdown]
# **TODO 10** - Create a scatter plot with the `dose1_staff` and `dose3_staff` columns.

# %%
sns.scatterplot(x=data['dose1_staff'], y=data['dose3_staff'])

# Add labels and title
plt.xlabel('Dose 1 Staff')
plt.ylabel('Dose 3 Staff')
plt.title('Scatter Plot of Dose 1 Staff vs Dose 3 Staff')

# Show the plot
plt.show()

# %% [markdown]
# **TODO 11** - Create a scatter plot with the `dose1_student` and `dose2_student` columns.

# %%
sns.scatterplot(x=data['dose1_student'], y=data['dose2_student'])

# Add labels and title
plt.xlabel('Dose 1 Student')
plt.ylabel('Dose 2 Student')
plt.title('Scatter Plot of Dose 1 Student vs Dose 2 Student')

# Show the plot
plt.show()

# %% [markdown]
# ## Asking and Answering Questions

# %% [markdown]
# Instructions (delete this cell)
#
# - Ask at 10 interesting questions about your dataset
# - Answer the questions either by computing the results using Numpy/Pandas or by plotting graphs using Matplotlib/Seaborn
# - Create new columns, merge multiple dataset and perform grouping/aggregation wherever necessary
# - Wherever you're using a library function from Pandas/Numpy/Matplotlib etc. explain briefly what it does

# %% [markdown]
# 1. Which school has the highest percentage of dose 1 vaccination for staff?

# %%
import pandas as pd

# Load the dataset
data = pd.read_csv('https://raw.githubusercontent.com/MoH-Malaysia/covid19-public/main/vaccination/vax_school.csv')

# Calculate the percentage of dose 1 vaccination for staff
data['percentage_dose1_staff'] = (data['dose1_staff'] / 100)  # Assuming dose1_staff is in percentage form

# Find the school with the highest percentage
school_with_highest_percentage = data[data['percentage_dose1_staff'] == data['percentage_dose1_staff'].max()]['school']

print("School with the highest percentage of dose 1 vaccination for staff:")
print(school_with_highest_percentage)
# Out:
# School with the highest percentage of dose 1 vaccination for staff:
# 0        SK TOH TANDEWA SAKTI
# 1            SK PENDITA ZA'BA
# 2                    SK BANIR
# 3                    SK TEMOH
# 4              SK CHENDERIANG
#                  ...
# 10209      SMK AGAMA MATANG 2
# 10212      SMK AGAMA SIBU (S)
# 10213          SMK AGAMA IGAN
# 10214               SMK AGAMA
# 10215       SMK AGAMA LIMBANG
# Name: school, Length: 8170, dtype: object

# %% [markdown]
# 2. What is the distribution of dose 2 vaccination percentages for students among all schools?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the dataset
data = pd.read_csv('https://raw.githubusercontent.com/MoH-Malaysia/covid19-public/main/vaccination/vax_school.csv')

# Create a histogram of dose 2 vaccination percentages for students
plt.hist(data['dose2_student'], bins=10, edgecolor='k')
plt.xlabel('Percentage of Dose 2 Vaccination for Students')
plt.ylabel('Number of Schools')
plt.title('Distribution of Dose 2 Vaccination Percentages for Students')
plt.show()

# %% [markdown]
# 3.  Is there a relationship between the percentage of dose 1 vaccination for staff and the percentage of dose 2 vaccination for students?

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the dataset
data = pd.read_csv('https://raw.githubusercontent.com/MoH-Malaysia/covid19-public/main/vaccination/vax_school.csv')

# Create a scatter plot
plt.scatter(data['dose1_staff'], data['dose2_student'])
plt.xlabel('Percentage of Dose 1 Vaccination for Staff')
plt.ylabel('Percentage of Dose 2 Vaccination for Students')
plt.title('Relationship Between Dose 1 Vaccination for Staff and Dose 2 Vaccination for Students')

# Calculate the correlation coefficient
correlation = np.corrcoef(data['dose1_staff'], data['dose2_student'])[0, 1]
print(f"Correlation coefficient: {correlation}")

plt.show()
# Out:
# Correlation coefficient: nan

# %% [markdown]
# 4. What is the correlation between doses given to staff and students?

# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import numpy as np

correlation = data[['dose1_staff', 'dose2_staff', 'dose3_staff', 'dose1_student', 'dose2_student']].corr()

sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.title('Correlation Between Doses')
plt.show()

# %% [markdown]
# *   We can better grasp the relationship between the doses administered to staff and students with the aid of this visualisation. It provide insights into whether there is a regular pattern or connection between the various dosage forms that are used.
# *   The degree and direction of the correlation between each pair of dose-related columns will be graphically represented in the resulting plot. Strong positive correlations are shown by values near 1, strong negative correlations by values near -1, and weak correlations by values near 0.

# %% [markdown]
# 5. How does the distribution of dose 1 for staff vary across different states?

# %%
sns.boxplot(x='state', y='dose1_staff', data=data)

# Title the plot
plt.title('Distribution of Dose 1 for Staff Across States')

#Show the plot
plt.show()

# %% [markdown]
# 6. Which school have high student that receive dose 1 and dose 2?

# %%
# Sort the DataFrame based on 'dose1_staff' and 'dose2_staff' columns in descending order
sorted_vax_cleaned = vax_cleaned.sort_values(by=['dose1_student', 'dose2_student'], ascending=False)

# Display the top rows with the highest staff dose1 and staff dose2
top_student_doses = sorted_vax_cleaned[['school', 'state', 'dose1_student', 'dose2_student']].head()

print(top_student_doses)
# Out:
#                 school state  dose1_student  dose2_student
# 3             SK TEMOH     8          100.0          100.0
# 4       SK CHENDERIANG     8          100.0          100.0
# 13  SK JERAM MENGKUANG     8          100.0          100.0
# 16      SK BATU MASJID     8          100.0          100.0
# 22          SK BATU 14     8          100.0          100.0

# %% [markdown]
# 7. What is the average longitude and latitude for school that received vaccination?

# %%
import matplotlib.pyplot as plt

# Calculate average latitude and longitude
avg_latitude = vax_cleaned['lat'].mean()
avg_longitude = vax_cleaned['lon'].mean()

# Visualize the location of schools
plt.scatter(vax_cleaned['lon'], vax_cleaned['lat'], alpha=0.5)
plt.scatter(avg_longitude, avg_latitude, color='red', marker='x', label='Average Location')
plt.title('School Locations and Average Location')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.legend()
plt.show()

# %% [markdown]
# 8. Is there any different between vaccination coverage between top 5 state and bottom 5 states?

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming your DataFrame is named 'vax_cleaned'
# Compute vaccination coverage for each state
state_vaccination_coverage = vax_cleaned.groupby('state').apply(lambda x: ((x['dose1_staff'] + x['dose2_staff']).sum() / (x['dose1_student'] + x['dose2_student']).sum()) * 100)

# Sort states based on vaccination coverage in descending order
sorted_states = state_vaccination_coverage.sort_values(ascending=False)

# Get the top 5 and bottom 5 states
top_5_states = sorted_states.head(5)
bottom_5_states = sorted_states.tail(5)

# Plotting side by side for top 5 and bottom 5 states using Matplotlib
fig, ax = plt.subplots(1, 2, figsize=(15, 6))

# Plotting the results for top 5 states
ax[0].bar(range(len(top_5_states)), top_5_states, align='center', alpha=0.7, color='green')
ax[0].set_xticks(range(len(top_5_states)))
ax[0].set_xticklabels(top_5_states.index, rotation='vertical')
ax[0].set_xlabel('State')
ax[0].set_ylabel('Vaccination Coverage (%)')
ax[0].set_title('Top 5 States')
for i, v in enumerate(top_5_states):
    ax[0].text(i, v + 1, f'{v:.2f}%', ha='center')

# Plotting the results for bottom 5 states
ax[1].bar(range(len(bottom_5_states)), bottom_5_states, align='center', alpha=0.7, color='red')
ax[1].set_xticks(range(len(bottom_5_states)))
ax[1].set_xticklabels(bottom_5_states.index, rotation='vertical')
ax[1].set_xlabel('State')
ax[1].set_ylabel('Vaccination Coverage (%)')
ax[1].set_title('Bottom 5 States')
for i, v in enumerate(bottom_5_states):
    ax[1].text(i, v + 1, f'{v:.2f}%', ha='center')

plt.tight_layout()
plt.show()

# %% [markdown]
# The result shows that state with high vaccination coverage is state 12
#  with 110.87%. while lowest vaccination coverage is 15 with 104.01%. Thus, shows Malaysia provide good distribution of vaccine to public school.

# %% [markdown]
# 9. What is the school that receive the highest dose 1?

# %%
vax_cleaned['dose_diff'] = vax_cleaned['dose1_student'] - vax_cleaned['dose2_student']
vax_cleaned_sorted = vax_cleaned.sort_values(by='dose_diff', ascending=False)
highest_diff_school = vax_cleaned_sorted.iloc[0]['school']
print("The school with the highest difference between the number of students receiving dose 1 and dose 2 is:", highest_diff_school)
# Out:
# The school with the highest difference between the number of students receiving dose 1 and dose 2 is: SJK(T) LADANG PASAK

# %% [markdown]
# 10. Based on answer above, is there any different of dose 1 for student and dose 1 for staff in SJK(T) Ladang Pasak?

# %%
import matplotlib.pyplot as plt
import seaborn as sns

school_name = 'SJK(T) LADANG PASAK'

# Filter the DataFrame for the specific school
school_data = vax_cleaned[vax_cleaned['school'] == school_name]

# Create a line plot to compare dose1 coverage between staff and students
plt.figure(figsize=(12, 6))
sns.lineplot(data=school_data['dose1_staff'], label='Dose 1 Staff Coverage')
sns.lineplot(data=school_data['dose1_student'], label='Dose 1 Student Coverage')

# Highlight the months where the vaccination coverage is at its peak for both staff and students
peak_dose1_staff_month = school_data['dose1_staff'].idxmax()
peak_dose1_student_month = school_data['dose1_student'].idxmax()

plt.scatter(peak_dose1_staff_month, school_data['dose1_staff'].max(), color='blue', marker='o', label=f'Dose 1 Staff Peak')
plt.scatter(peak_dose1_student_month, school_data['dose1_student'].max(), color='orange', marker='o', label=f'Dose 1 Student Peak')

# Customize the plot
plt.title(f'Dose 1 Coverage Comparison Between Staff and Students for {school_name}')
plt.ylabel('Dose 1 Vaccination Coverage')
plt.legend()
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Inferences and Conclusion

# %% [markdown]
# In the context of a COVID-19 vaccination dataset specific to Malaysian schools, several crucial data preparation and analysis steps are carried out to ensure that the data is reliable and valuable for decision-making. These steps are fundamental in understanding the vaccination coverage and the associated trends within the school population. Let's delve into these steps in more detail:
#
# **Data Preparation:**
#
#
# **Loading the Dataset:** The first step in any data analysis process is to acquire the dataset. This may involve retrieving data from official sources, APIs, or databases. Once the data is obtained, it needs to be imported into the chosen data analysis tools, such as spreadsheet software or programming languages like Python or R.
#
#
# **Handling Missing Values:** Datasets are rarely perfect and often contain missing or incomplete information. Handling missing values is a critical data preparation step. This can involve strategies like imputation (replacing missing values with estimated ones) or removing incomplete records to ensure data integrity.
#
#
# **Changing Data Types:** To perform meaningful analysis, data types might need to be adjusted. For instance, dates or strings might need to be converted to date-time objects or numeric values. This is essential for proper visualization and calculation.
#
#
# **Data Cleaning:** Data cleaning involves removing any outliers, inconsistencies, or errors in the dataset. This step ensures that the data is accurate and consistent. For vaccination data, this could include checking for improbable values, duplicate entries, or any other issues that might affect the analysis.
#
#
# **Data Analysis:**
#
#
# **Exploring the Data:** Once the data is prepared, the next step is to explore it thoroughly. This involves calculating summary statistics, such as the mean, median, and standard deviation of vaccination rates. Exploratory data analysis (EDA) is often performed at this stage to identify any initial patterns or insights in the data.
#
#
# **Visualizing Vaccination Distributions:** Visualizations are powerful tools for conveying insights from the data. Creating graphs and charts, such as bar plots, histograms, or choropleth maps, can help in visualizing the distribution of vaccination rates among different schools or regions. These visualizations can reveal trends and disparities that might not be immediately evident in tabular data.
#
#
# **Answering Questions about the Dataset:** Once the data is explored and visualized, specific questions can be addressed. These questions could range from understanding the overall vaccination coverage in Malaysian schools to investigating disparities between different regions or school types. Data analysis helps in quantifying and providing evidence for these observations.
#
#
# In summary, the process of preparing and analyzing a COVID-19 vaccination dataset in Malaysian schools involves a series of meticulous steps to ensure data accuracy and to draw meaningful insights for public health and policy-making.

# %% [markdown]
# ## References and Future Work

# %% [markdown]
# - Ngo, H. (n.d.). How to Clean Your Data in Python. A detailed guide on how to clean your… | by Huong Ngo. Towards Data Science. Retrieved November 11, 2023, from https://towardsdatascience.com/how-to-clean-your-data-in-python-8f178638b98d
