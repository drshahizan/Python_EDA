# %%
# !pip install dtale

# %%
import dtale
import pandas as pd

# %%
path = 'C:/Users/user/Downloads/cases_state.csv'

df = pd.read_csv(path)

# %%
dtale.show(df)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://LAPTOP-533SDKRI:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
