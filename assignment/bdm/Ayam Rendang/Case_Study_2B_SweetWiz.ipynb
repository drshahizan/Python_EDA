# %% [markdown]
# <a href="https://colab.research.google.com/github/drshahizan/Python_EDA/blob/main/assignment/bdm/Ayam%20Rendang/Case_Study_2B_SweetWiz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exploratory Data Analysis (EDA) in Python using Sweetviz

# %%
pip install sweetviz
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 82.1 MB/s eta 0:00:00
# ...

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/drshahizan/Python_EDA/main/assignment/bdm/Ayam%20Rendang/NEW_cleaned_mudah-apartment-kl-selangor.csv')

# Separate X and Y
X = df.drop('Property_name', axis=1)
Y = df['Property_name']

# %%
X
# Out:
#       monthly_rent(RM)               location      property_type rooms  \
# 0                4 200             Taman Desa        Condominium     5
# 1                2 300                 Cheras        Condominium     3
# 2                1 700                    tul          Apartment     2
# 3                1 299             Mont Kiara  Service Residence     1
# 4                1 500                  tapak          Apartment     3
# ...                ...                    ...                ...   ...
# 12552            1 800           Kuala Langat  Service Residence     4
# 12553            1 300   Bandar Saujana Putra  Service Residence     4
# 12554            1 350                 Kajang        Condominium     3
# 12555            1 200              Cyberjaya  Service Residence     3
# 12556            1 000              Cyberjaya             Studio     1
#
#        parking  bathroom  size(sq.ft)         furnish_info  \
# ...

# %% [markdown]
# # Analyze The Dataset

# %%
df.head()
# Out:
#                   Property_name monthly_rent(RM)    location  \
# 0      The Hipster @ Taman Desa            4 200  Taman Desa
# 1                  Segar Courts            2 300      Cheras
# 2  Sentul Point Suite Apartment            1 700         tul
# 3               Arte Mont Kiara            1 299  Mont Kiara
# 4      Residensi Vista Wirajaya            1 500       tapak
#
#        property_type rooms  parking  bathroom  size(sq.ft)  \
# 0        Condominium     5        2         6         1842
# 1        Condominium     3        1         2         1170
# 2          Apartment     2        1         2          743
# 3  Service Residence     1        1         1          494
# 4          Apartment     3        1         2          884
#
#           furnish_info                                         facilities  \
# 0      Fully Furnished  Minimart, Gymnasium, Security, Playground, Swi...
# 1  Partially Furnished  Playground, Parking, Barbeque area, Security, ...
# ...

# %%
import sweetviz as sv
analyze_report = sv.analyze(df)
analyze_report.show_html('analyze.html', open_browser=False)
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report analyze.html was generated.

# %%
import IPython
IPython.display.HTML('analyze.html')
# Out:
# <!doctype html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <link rel="icon" href="data:image/x-icon;base64,..." type="image/x-icon" />
#         <script> /*! jQuery v3.4.1 | (c) JS Foundation and other contributors | jquery.org/license */
# ...

# %% [markdown]
# # Side by Side Comparison of Train vs Test Set

# %% [markdown]
# ## Data Split using 80/20 Split Ratio

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2)

# %%
X_train
# Out:
#       monthly_rent(RM)        location      property_type rooms  parking  \
# 6758             1 100       Cyberjaya  Service Residence     3        1
# 10717            1 200      Batu Caves  Service Residence     3        2
# 10001            1 050     Subang Jaya          Apartment     1        1
# 6307               900      Taman Desa          Apartment     2        1
# 3605               700   Jalan Kuching          Apartment     3        1
# ...                ...             ...                ...   ...      ...
# 8247             1 300         Puchong          Apartment     3        1
# 4261             1 900             mat          Apartment     3        1
# 6976             1 000       Shah Alam          Apartment     3        1
# 2194             1 700       chai Lama        Condominium     3        1
# 5683             1 700  Old Klang Road        Condominium     3        1
#
#        bathroom  size(sq.ft)         furnish_info  \
# ...

# %%
X_test
# Out:
#       monthly_rent(RM)       location      property_type rooms  parking  \
# 6372             1 800         Cheras        Condominium     2        2
# 387              2 200    i Damansara        Condominium     1        1
# 9974             1 200         Sepang        Condominium     3        2
# 8140               850     Batu Caves          Apartment     3        1
# 4813             1 500  Jalan Kuching        Condominium     3        1
# ...                ...            ...                ...   ...      ...
# 10985            6 888    Subang Jaya  Service Residence     6        4
# 156              1 300         Cheras          Apartment     3        2
# 4113             1 400         Cheras  Service Residence     2        1
# 9909             1 300         Kajang          Apartment     3        2
# 7716             1 200         Cheras        Condominium     3        1
#
#        bathroom  size(sq.ft)         furnish_info  \
# 6372          2          833      Fully Furnished
# ...

# %% [markdown]
# ## Comparison Report

# %%
import sweetviz as sv
compare_report = sv.compare([X_train, 'Train'], [X_test, 'Test'])
compare_report.show_html('compare.html', open_browser=False)
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report compare.html was generated.

# %%
import IPython
IPython.display.HTML('compare.html')
# Out:
# <!doctype html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <link rel="icon" href="data:image/x-icon;base64,..." type="image/x-icon" />
#         <script> /*! jQuery v3.4.1 | (c) JS Foundation and other contributors | jquery.org/license */
# ...

# %% [markdown]
# ### **The relationships and patterns in the data**
#
# The graph shows the numerical correlations between the different property types. It indicates how strong the correlation is.
#
# The information that we gain through the graph are: -
#
# 1. Size and Bathrooms - Strong Positive Relationship
#
#   Size and Bathrooms  is the significant factor influencing property monthly rental. The rental people preferences, location, facilities, market demand, and convenience can all contribute to this strong positive correlation.
#
# 2. Parking and Size (Positively - strong)
#
#   Properties that offer higher number of parking tend to command bigger house size. This is often due to factors such as tend to have more rooms in a house to accomudate more people, less public transportation facilities, or more.
#
# 3. Rooms and Size
#
#   More number of rooms often has bigger house size which often relates. There appears to be a substantial positive link between certain property kinds and larger properties, which generally have more rooms.

# %% [markdown]
# ###**Pro and Cons Analysis**
#
# **Pros:**
#
#
# *   Sweetviz is a helpful tool for collaboration and stakeholder communication since it creates interactive HTML reports that are simple to share with others.
#
# *   It enables us to explore our dataset quickly and effectively. With just one command, it produces thorough statistics and visualisations.
#
# **Cons:**
#
#
# *   It does not provide future statistical testing; it is just works as a visualisation tool.

# %% [markdown]
# ### **Conclusion & Recommendation**
#
# **Key Findings and Insights:**
#
# * The matrix graph provided a clear visual representation of the relationships and patterns in the data that been provided for analysation.
# * The findings included strong positive relationship between Size and Bathroom, indicating that property size significantly influences property number of bathrooms. Parking and Size also exhibited a strong positive relationship.
# * The correlation between the number of rooms and the size of the property demonstrated how different property kinds are linked to varied room counts, which represent the preferences of customers and features of the property.
#
#
#
# **Recommendations on Tool Suitability:**
#
# * It's a great option for quick data exploration, when we need to analyse the dataset quickly.
# * It is also helpful for testing and validating models since it can be used to compare datasets and identify differences and similarities.

# %% [markdown]
# **This task was completed with help of a YouTube:-**
#
# DataProfessor, (November 19, 2020) "How to Quickly Perform Exploratory Data Analysis (EDA) in Python using Sweetviz"
# https://www.youtube.com/watch?v=UR_OK8vBpeY&t=177s&ab_channel=DataProfessor
